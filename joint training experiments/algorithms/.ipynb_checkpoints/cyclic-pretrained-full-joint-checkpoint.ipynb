# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms, utils
from torch.utils.data import DataLoader
# %cd "C:/Users/mateo/Desktop/polymath-jr-drifting"
# This notebook uses DriftXpress; exact drift uses its separate loss/cache API in src.drift.
from src.driftXpress import *
from src.eval import (
    evaluate_latent_model,
    evaluate_generation,
    plot_conditional_mnist_results,
    plot_real_generated_projections,
    plot_loss_history,
    latent_statistics
)
from src.training import (
    compose_objective,
    format_epoch_losses,
    gradient_report,
    per_loss_gradient_norms,
    set_requires_grad,
)
torch.manual_seed(7)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# C:\Users\mateo\Desktop\polymath-jr-drifting
# Using: cuda

# %%
transform = transforms.ToTensor()

SELECTED_DIGITS = (0, 8, 2, 4, 7, 9)
DIGIT_TO_CLASS = {digit: index for index, digit in enumerate(SELECTED_DIGITS)}
CLASS_TO_DIGIT = np.asarray(SELECTED_DIGITS)

train_data = datasets.MNIST("data", train=True, download=True, transform=transform)
test_data = datasets.MNIST("data", train=False, download=True, transform=transform)

def keep_selected_digits(dataset):
    selected = torch.tensor(SELECTED_DIGITS, dtype=dataset.targets.dtype)
    mask = torch.isin(dataset.targets, selected)
    dataset.data = dataset.data[mask]
    raw_targets = dataset.targets[mask]
    dataset.targets = torch.tensor(
        [DIGIT_TO_CLASS[int(digit)] for digit in raw_targets],
        dtype=torch.long,
    )
    return dataset

train_data = keep_selected_digits(train_data)
test_data = keep_selected_digits(test_data)

BATCH_SIZE = 500

train_loader = DataLoader(
    train_data,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)
test_loader = DataLoader(
    test_data,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)

print("Selected digits:", SELECTED_DIGITS)
print("Train samples:", len(train_data))
print("Test samples:", len(test_data))
# Out:
# Selected digits: (0, 8, 2, 4, 7, 9)
# Train samples: 35788
# Test samples: 6005

# %%
class f(nn.Module):
    def __init__(self, input_dim=784, latent_dim=16, num_classes=6, label_dim=16):
        super().__init__()
        self.latent_dim = latent_dim
        self.num_classes = num_classes
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 192), nn.LeakyReLU(0.2),
            nn.Linear(192, 96), nn.LeakyReLU(0.2),
        )
        self.fc_mu = nn.Linear(96, latent_dim)
        self.fc_var = nn.Linear(96, latent_dim)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 96), nn.LeakyReLU(0.2),
            nn.Linear(96, 192), nn.LeakyReLU(0.2),
            nn.Linear(192, input_dim), nn.Sigmoid(),
        )
        self.embedding = nn.Embedding(num_classes, label_dim)
        self.generator = nn.Sequential(
            nn.Linear(latent_dim + label_dim, 48), nn.SiLU(),
            nn.Linear(48, 48), nn.SiLU(),
            nn.Linear(48, 48), nn.SiLU(),
            nn.Linear(48, latent_dim),
        )

    def reparameterize(self, mu, logvar):
        return mu + torch.randn_like(logvar) * torch.exp(0.5 * logvar)

    def get_latent(self, x):
        h = self.encoder(x)
        mu, logvar = self.fc_mu(h), self.fc_var(h)
        return mu, logvar, self.reparameterize(mu, logvar)

    def encode_mu(self, x):
        return self.fc_mu(self.encoder(x))

    def decode(self, z):
        return self.decoder(z)

    def generate(self, noise, labels):
        h = torch.cat([noise, self.embedding(labels.long())], dim=1)
        z = self.generator(h)
        return z, self.decode(z)

# %%
model = f(input_dim=784, latent_dim=32, num_classes=6)
print(f"Total parameters: {sum(parameter.numel() for parameter in model.parameters())}")
print(f"Trainable parameters: {sum(parameter.numel() for parameter in model.parameters() if parameter.requires_grad)}")
# Out:
# Total parameters: 357280
# Trainable parameters: 357280

# %%
def pretrain_vae(model, data_loader, epochs, lambda_kl, lambda_var, lambda_cov, lr=1e-3):
    """Pretrain the VAE side of one joint model; generator parameters are frozen."""
    vae_parameters = (
        list(model.encoder.parameters())
        + list(model.fc_mu.parameters())
        + list(model.fc_var.parameters())
        + list(model.decoder.parameters())
    )
    generator_parameters = (
        list(model.embedding.parameters()) + list(model.generator.parameters())
    )
    for parameter in generator_parameters:
        parameter.requires_grad_(False)

    optimizer = optim.AdamW(vae_parameters, lr=lr)
    history = {key: [] for key in ("total", "recon", "kl", "var", "covar")}
    print(f"Pretraining the VAE part for {epochs} epochs (generator frozen)...")

    for epoch in range(1, epochs + 1):
        model.train()
        items = {key: 0.0 for key in history}
        for images, _ in data_loader:
            x = images.to(device, non_blocking=True).flatten(start_dim=1)
            mu, logvar, z = model.get_latent(x)
            reconstruction = model.decode(z)
            L_recon = recon_loss(reconstruction, x)
            L_kl = kl_loss(mu, logvar)
            L_var = variance_loss(mu)
            L_cov = covariance_loss(mu)
            loss, _ = compose_objective(
                {"recon": L_recon, "kl": L_kl, "var": L_var, "covar": L_cov},
                {"kl": lambda_kl, "var": lambda_var, "covar": lambda_cov},
            )

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(vae_parameters, max_norm=5.0)
            optimizer.step()

            items["total"] += loss.item()
            items["recon"] += L_recon.item()
            items["kl"] += L_kl.item()
            items["var"] += L_var.item()
            items["covar"] += L_cov.item()

        for key in items:
            items[key] /= len(data_loader)
            history[key].append(items[key])
        if epoch == 1 or epoch % 5 == 0 or epoch == epochs:
            print(f"-------- VAE pretrain epoch {epoch}/{epochs} --------")
            print(format_epoch_losses(
                {key: items[key] for key in ("recon", "kl", "var", "covar")},
                {"kl": lambda_kl, "var": lambda_var, "covar": lambda_cov},
            ))

    for parameter in generator_parameters:
        parameter.requires_grad_(True)
    return history


def warmup_generator(model, data_loader, epochs, lr=1e-3):
    """Warm up the conditional generator against frozen VAE means."""
    vae_parameters = (
        list(model.encoder.parameters())
        + list(model.fc_mu.parameters())
        + list(model.fc_var.parameters())
        + list(model.decoder.parameters())
    )
    generator_parameters = (
        list(model.embedding.parameters()) + list(model.generator.parameters())
    )
    for parameter in vae_parameters:
        parameter.requires_grad_(False)
    for parameter in generator_parameters:
        parameter.requires_grad_(True)

    optimizer = optim.AdamW(generator_parameters, lr=lr)
    history = {"total": [], "latent_match": []}
    print(f"Warming up the generator for {epochs} epochs (VAE frozen)...")

    for epoch in range(1, epochs + 1):
        model.train()
        total = 0.0
        latent_match = 0.0
        for images, class_ids in data_loader:
            x = images.to(device, non_blocking=True).flatten(start_dim=1)
            class_ids = class_ids.to(device, non_blocking=True)
            noise = torch.randn(x.shape[0], model.latent_dim, device=device)
            with torch.no_grad():
                target_mu = model.encode_mu(x)
            generated_latents, _ = model.generate(noise, class_ids)
            loss = F.mse_loss(generated_latents, target_mu)

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(generator_parameters, max_norm=5.0)
            optimizer.step()

            total += loss.item()
            latent_match += loss.item()

        total /= len(data_loader)
        latent_match /= len(data_loader)
        history["total"].append(total)
        history["latent_match"].append(latent_match)
        if epoch == 1 or epoch % 5 == 0 or epoch == epochs:
            print(f"-------- Generator warmup epoch {epoch}/{epochs} --------")
            print(f"latent_match={latent_match:.6f}")

    for parameter in vae_parameters:
        parameter.requires_grad_(True)
    return history


def build_conditional_drift_cache(model, data_loader, num_classes, num_landmarks, T):
    """Build the fixed class-conditional DriftXpress cache after pretraining."""
    model.eval()
    references = {class_id: [] for class_id in range(num_classes)}
    with torch.no_grad():
        for images, class_ids in data_loader:
            x = images.to(device, non_blocking=True).flatten(start_dim=1)
            # Use deterministic encoder means for a stable cache.
            z = model.encode_mu(x)
            class_ids = class_ids.to(device, non_blocking=True)
            for class_id in range(num_classes):
                mask = class_ids == class_id
                if mask.any():
                    references[class_id].append(z[mask].detach())

    cache = {}
    for class_id in range(num_classes):
        if not references[class_id]:
            raise ValueError(f"No reference samples found for class {class_id}.")
        support = torch.cat(references[class_id], dim=0)
        landmarks = select_landmarks(support, num_landmarks)
        K_uu_inv_sqrt = build_nystrom_cache(landmarks, T)
        Ap, bp = pre_compute_summaries(support, landmarks, K_uu_inv_sqrt, T)
        cache[class_id] = (landmarks, K_uu_inv_sqrt, Ap, bp)
    return cache


def conditional_drift_loss(generated, class_ids, cache, T):
    total = generated.new_zeros(())
    field = torch.zeros_like(generated)
    for class_tensor in torch.unique(class_ids):
        class_id = int(class_tensor.item())
        mask = class_ids == class_id
        landmarks, K_uu_inv_sqrt, Ap, bp = cache[class_id]
        class_loss, class_field = drift_loss(
            generated[mask], landmarks, K_uu_inv_sqrt, Ap, bp, T
        )
        total = total + mask.float().mean() * class_loss
        field[mask] = class_field
    return total, field


def warmup_generator_drift(
    model, data_loader, epochs, cache, T, lambda_drift=1.0,
    raw_drift_weight=0.25, lr=1e-4,
):
    """Warm up only the generator with the actual fixed DriftXpress field."""
    vae_parameters = (
        list(model.encoder.parameters())
        + list(model.fc_mu.parameters())
        + list(model.fc_var.parameters())
        + list(model.decoder.parameters())
    )
    generator_parameters = (
        list(model.embedding.parameters()) + list(model.generator.parameters())
    )
    for parameter in vae_parameters:
        parameter.requires_grad_(False)
    for parameter in generator_parameters:
        parameter.requires_grad_(True)

    optimizer = optim.AdamW(generator_parameters, lr=lr)
    history = {key: [] for key in ("total", "drift", "drift_raw", "force")}
    print(f"Warming up the generator with DriftXpress for {epochs} epochs (VAE frozen)...")

    for epoch in range(1, epochs + 1):
        model.train()
        items = {key: 0.0 for key in history}
        for images, class_ids in data_loader:
            x = images.to(device, non_blocking=True).flatten(start_dim=1)
            class_ids = class_ids.to(device, non_blocking=True)
            noise = torch.randn(x.shape[0], model.latent_dim, device=device)
            z_raw, x_neg = model.generate(noise, class_ids)
            z_reencoded = model.encode_mu(x_neg)
            L_drift_reencoded, V = conditional_drift_loss(z_reencoded, class_ids, cache, T)
            L_drift_raw, _ = conditional_drift_loss(z_raw, class_ids, cache, T)
            L_drift = L_drift_reencoded + raw_drift_weight * L_drift_raw
            loss = lambda_drift * L_drift

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(generator_parameters, max_norm=5.0)
            optimizer.step()

            items["total"] += loss.item()
            items["drift"] += L_drift_reencoded.item()
            items["drift_raw"] += L_drift_raw.item()
            items["force"] += V.norm(dim=1).mean().item()

        for key in items:
            items[key] /= len(data_loader)
            history[key].append(items[key])
        if epoch == 1 or epoch % 5 == 0 or epoch == epochs:
            print(f"-------- Generator DriftXpress warmup epoch {epoch}/{epochs} --------")
            print(f"drift={items['drift']:.6f} raw_drift={items['drift_raw']:.6f} total={items['total']:.6f} average |V|={items['force']:.6f}")

    for parameter in vae_parameters:
        parameter.requires_grad_(True)
    return history


def training_loop(
    num_epochs,
    T,
    num_landmarks,
    lambda_kl,
    lambda_drift,
    lambda_var,
    lambda_cov,
    lambda_representation=1.0,
    loss_scale=1.0,
    vae_pretrain_epochs=50,
    generator_warmup_epochs=30,
    generator_drift_warmup_epochs=25,
    generator_lr=1e-3,
    generator_drift_lr=1e-4,
    joint_generator_lr=1e-4,
    joint_vae_lr=1e-5,
    raw_drift_weight=0.25,
    lr=1e-4,
):
    global DRIFT_CACHE
    model = f(784, LATENT_DIM, NUM_CLASSES).to(device)
    pretrain_history = pretrain_vae(
        model,
        train_loader,
        vae_pretrain_epochs,
        lambda_kl=lambda_kl,
        lambda_var=lambda_var,
        lambda_cov=lambda_cov,
        lr=lr,
    )

    print("Building the fixed conditional DriftXpress cache once, after pretraining...")
    cache_start = time.perf_counter()
    DRIFT_CACHE = build_conditional_drift_cache(
        model, train_loader, NUM_CLASSES, num_landmarks, T
    )
    print(f"Fixed attraction caches built in {(time.perf_counter() - cache_start) / 60:.2f} minutes")

    generator_warmup_history = warmup_generator(
        model,
        train_loader,
        epochs=generator_warmup_epochs,
        lr=generator_lr,
    )

    generator_drift_history = warmup_generator_drift(
        model,
        train_loader,
        epochs=generator_drift_warmup_epochs,
        cache=DRIFT_CACHE,
        T=T,
        lambda_drift=lambda_drift,
        raw_drift_weight=raw_drift_weight,
        lr=generator_drift_lr,
    )

    vae_parameters = (
        list(model.encoder.parameters())
        + list(model.fc_mu.parameters())
        + list(model.fc_var.parameters())
        + list(model.decoder.parameters())
    )
    generator_parameters = (
        list(model.embedding.parameters()) + list(model.generator.parameters())
    )
    optimizer = optim.AdamW([
        {"params": generator_parameters, "lr": joint_generator_lr},
        {"params": vae_parameters, "lr": joint_vae_lr},
    ])
    print(
        f"Joint learning rates: generator={joint_generator_lr:g}, "
        f"VAE/encoder-decoder={joint_vae_lr:g}"
    )
    history = {key: [] for key in ("total", "recon", "kl", "drift", "drift_raw", "var", "covar", "force")}
    evolution = []
    snapshots = set(range(0, num_epochs + 1, max(1, num_epochs // 5)))
    snapshots.add(num_epochs)
    train_start = time.perf_counter()
    print("Pretrained fully joint conditional training started")

    for epoch in range(num_epochs + 1):
        model.train()
        items = {key: 0.0 for key in history}
        last_pos, last_neg = None, None
        for images, class_ids in train_loader:
            x = images.to(device, non_blocking=True).flatten(start_dim=1)
            class_ids = class_ids.to(device, non_blocking=True)
            noise = torch.randn(x.shape[0], model.latent_dim, device=device)

            mu, logvar, z_pos = model.get_latent(x)
            x_recon = model.decode(z_pos)
            z_raw, x_neg = model.generate(noise, class_ids)
            z_neg = model.encode_mu(x_neg)

            # Main fully joint route: drift on the re-encoded generated image.
            L_drift_reencoded, V = conditional_drift_loss(
                z_neg, class_ids, DRIFT_CACHE, T
            )
            # Auxiliary raw-latent route keeps the generator close to the cached
            # latent coordinate system while the decoder/encoder remain trainable.
            L_drift_raw, _ = conditional_drift_loss(
                z_raw, class_ids, DRIFT_CACHE, T
            )
            L_drift = L_drift_reencoded + raw_drift_weight * L_drift_raw
            L_recon = recon_loss(x_recon, x)
            L_kl = kl_loss(mu, logvar)
            L_var = variance_loss(mu) + variance_loss(z_neg)
            L_cov = covariance_loss(mu) + covariance_loss(z_neg)
            loss, _ = compose_objective(
                {
                    "recon": L_recon,
                    "kl": L_kl,
                    "drift": L_drift,
                    "var": L_var,
                    "covar": L_cov,
                },
                {
                    "kl": lambda_kl,
                    "drift": lambda_drift,
                    "var": lambda_var,
                    "covar": lambda_cov,
                },
                lambda_representation=lambda_representation,
                loss_scale=loss_scale,
            )
            if not torch.isfinite(loss):
                raise FloatingPointError(f"Non-finite loss at epoch {epoch}: {loss.item()}")

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
            optimizer.step()

            items["total"] += loss.item()
            items["recon"] += L_recon.item()
            items["kl"] += L_kl.item()
            items["drift"] += L_drift.item()
            items["drift_raw"] += L_drift_raw.item()
            items["var"] += L_var.item()
            items["covar"] += L_cov.item()
            items["force"] += V.norm(dim=1).mean().item()
            last_pos, last_neg = z_pos.detach(), z_neg.detach()

        for key in items:
            items[key] /= len(train_loader)
            history[key].append(items[key])
        if epoch in snapshots:
            evolution.append({
                "epoch": epoch,
                "pos": last_pos.cpu().numpy(),
                "neg": last_neg.cpu().numpy(),
            })
        if epoch < 20 or epoch % 10 == 0 or epoch == num_epochs:
            print(f"-------- Epoch {epoch} --------")
            print(format_epoch_losses(
                {key: items[key] for key in ("recon", "kl", "drift", "var", "covar")},
                {
                    "kl": lambda_kl,
                    "drift": lambda_drift,
                    "var": lambda_var,
                    "covar": lambda_cov,
                },
                lambda_representation=lambda_representation,
                loss_scale=loss_scale,
            ))
            print(
                f"reencoded drift={items['drift'] - raw_drift_weight * items['drift_raw']:.6f} "
                f"raw drift={items['drift_raw']:.6f}"
            )
            print("distances", torch.cdist(z_pos[:50], z_pos[:50]).mean().item())
            print(f"average |V|={items['force']:.6f}")
            print(f"latent std positive={last_pos.std(dim=0).mean().item():.6f}")
            print(f"latent std negative={last_neg.std(dim=0).mean().item():.6f}")

    elapsed = (time.perf_counter() - train_start) / 60
    print(f"Finished. Joint training took {elapsed:.2f} minutes")
    return (
        model,
        history["total"],
        history["recon"],
        history["kl"],
        history["drift"],
        history["var"],
        history["covar"],
        history["force"],
        evolution,
        pretrain_history,
        generator_warmup_history,
        generator_drift_history,
        history["drift_raw"],
    )

# %%
def run_joint_phase(
    model,
    data_loader,
    epochs,
    T,
    cache,
    lambda_kl,
    lambda_drift,
    lambda_var,
    lambda_cov,
    lambda_representation,
    loss_scale,
    joint_generator_lr,
    joint_vae_lr,
    raw_drift_weight,
    cycle_number,
    evolution,
):
    """Run one fully joint phase with a fixed cache for that phase."""
    vae_parameters = (
        list(model.encoder.parameters())
        + list(model.fc_mu.parameters())
        + list(model.fc_var.parameters())
        + list(model.decoder.parameters())
    )
    generator_parameters = (
        list(model.embedding.parameters()) + list(model.generator.parameters())
    )
    optimizer = optim.AdamW([
        {"params": generator_parameters, "lr": joint_generator_lr},
        {"params": vae_parameters, "lr": joint_vae_lr},
    ])
    history = {
        key: []
        for key in ("total", "recon", "kl", "drift", "drift_raw", "var", "covar", "force")
    }
    snapshots = set(range(0, epochs + 1, max(1, epochs // 4)))
    snapshots.add(epochs)
    print(
        f"Cycle {cycle_number}: fully joint training for {epochs} epochs "
        f"(generator lr={joint_generator_lr:g}, VAE lr={joint_vae_lr:g})"
    )

    for epoch in range(epochs + 1):
        model.train()
        items = {key: 0.0 for key in history}
        last_pos, last_neg = None, None

        for images, class_ids in data_loader:
            x = images.to(device, non_blocking=True).flatten(start_dim=1)
            class_ids = class_ids.to(device, non_blocking=True)
            noise = torch.randn(x.shape[0], model.latent_dim, device=device)

            mu, logvar, z_pos = model.get_latent(x)
            x_recon = model.decode(z_pos)
            z_raw, x_neg = model.generate(noise, class_ids)
            z_neg = model.encode_mu(x_neg)

            # Fully joint route: the re-encoded generated image receives drift gradients.
            L_drift_reencoded, V = conditional_drift_loss(z_neg, class_ids, cache, T)
            L_drift_raw, _ = conditional_drift_loss(z_raw, class_ids, cache, T)
            L_drift = L_drift_reencoded + raw_drift_weight * L_drift_raw
            L_recon = recon_loss(x_recon, x)
            L_kl = kl_loss(mu, logvar)
            L_var = variance_loss(mu) + variance_loss(z_neg)
            L_cov = covariance_loss(mu) + covariance_loss(z_neg)
            loss, _ = compose_objective(
                {
                    "recon": L_recon,
                    "kl": L_kl,
                    "drift": L_drift,
                    "var": L_var,
                    "covar": L_cov,
                },
                {
                    "kl": lambda_kl,
                    "drift": lambda_drift,
                    "var": lambda_var,
                    "covar": lambda_cov,
                },
                lambda_representation=lambda_representation,
                loss_scale=loss_scale,
            )
            if not torch.isfinite(loss):
                raise FloatingPointError(
                    f"Non-finite loss at cycle {cycle_number}, epoch {epoch}: {loss.item()}"
                )

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
            optimizer.step()

            items["total"] += loss.item()
            items["recon"] += L_recon.item()
            items["kl"] += L_kl.item()
            items["drift"] += L_drift.item()
            items["drift_raw"] += L_drift_raw.item()
            items["var"] += L_var.item()
            items["covar"] += L_cov.item()
            items["force"] += V.norm(dim=1).mean().item()
            last_pos, last_neg = z_pos.detach(), z_neg.detach()

        for key in items:
            items[key] /= len(data_loader)
            history[key].append(items[key])

        if epoch in snapshots:
            evolution.append({
                "cycle": cycle_number,
                "phase": "joint",
                "epoch": epoch,
                "pos": last_pos.cpu().numpy(),
                "neg": last_neg.cpu().numpy(),
            })

        if epoch < 5 or epoch % 10 == 0 or epoch == epochs:
            print(f"-------- Cycle {cycle_number}, joint epoch {epoch} --------")
            print(format_epoch_losses(
                {key: items[key] for key in ("recon", "kl", "drift", "var", "covar")},
                {
                    "kl": lambda_kl,
                    "drift": lambda_drift,
                    "var": lambda_var,
                    "covar": lambda_cov,
                },
                lambda_representation=lambda_representation,
                loss_scale=loss_scale,
            ))
            print(
                f"reencoded drift={items['drift'] - raw_drift_weight * items['drift_raw']:.6f} "
                f"raw drift={items['drift_raw']:.6f}"
            )
            print("distances", torch.cdist(last_pos[:50], last_pos[:50]).mean().item())
            print(f"average |V|={items['force']:.6f}")
            print(f"latent std positive={last_pos.std(dim=0).mean().item():.6f}")
            print(f"latent std negative={last_neg.std(dim=0).mean().item():.6f}")

    return history


def cyclic_training_loop(
    initial_vae_epochs,
    num_cycles,
    cycle_vae_epochs,
    cycle_generator_epochs,
    cycle_drift_epochs,
    cycle_joint_epochs,
    T,
    num_landmarks,
    lambda_kl,
    lambda_drift,
    lambda_var,
    lambda_cov,
    lambda_representation=1.0,
    loss_scale=1.0,
    vae_lr=1e-4,
    generator_lr=1e-3,
    generator_drift_lr=1e-4,
    joint_generator_lr=1e-4,
    joint_vae_lr=1e-5,
    raw_drift_weight=0.25,
    rebuild_cache_each_cycle=True,
):
    """Repeat short VAE, generator, DriftXpress, and joint phases.

    The attraction summaries are fixed during each generator/joint phase. They are
    rebuilt only after a VAE phase changes the encoder representation.
    """
    global DRIFT_CACHE
    model = f(784, LATENT_DIM, NUM_CLASSES).to(device)
    evolution = []
    generation_evolution = []
    phase_history = []

    # Fixed labels and noise make the generated-image snapshots comparable.
    evolution_class_ids = torch.arange(NUM_CLASSES, device=device)
    evolution_noise = torch.randn(NUM_CLASSES, model.latent_dim, device=device)

    def capture_generation(stage, cycle):
        model.eval()
        with torch.no_grad():
            _, generated = model.generate(evolution_noise, evolution_class_ids)
        generation_evolution.append({
            "cycle": cycle,
            "stage": stage,
            "class_ids": evolution_class_ids.cpu().numpy(),
            "images": generated.view(-1, 1, 28, 28).cpu().numpy(),
        })

    initial_vae_history = pretrain_vae(
        model,
        train_loader,
        initial_vae_epochs,
        lambda_kl=lambda_kl,
        lambda_var=lambda_var,
        lambda_cov=lambda_cov,
        lr=vae_lr,
    )
    phase_history.append(("initial VAE pretraining", initial_vae_history))
    capture_generation("after initial VAE pretraining", 0)

    print("Building the initial conditional DriftXpress cache...")
    cache_start = time.perf_counter()
    DRIFT_CACHE = build_conditional_drift_cache(
        model, train_loader, NUM_CLASSES, num_landmarks, T
    )
    print(f"Initial cache built in {(time.perf_counter() - cache_start) / 60:.2f} minutes")

    cycle_records = []
    combined_joint_history = {
        key: []
        for key in ("total", "recon", "kl", "drift", "drift_raw", "var", "covar", "force")
    }

    for cycle in range(1, num_cycles + 1):
        print(f"\n================ CYCLE {cycle}/{num_cycles} ================")

        cycle_vae_history = pretrain_vae(
            model,
            train_loader,
            cycle_vae_epochs,
            lambda_kl=lambda_kl,
            lambda_var=lambda_var,
            lambda_cov=lambda_cov,
            lr=vae_lr,
        )
        phase_history.append((f"cycle {cycle}: VAE warm-up", cycle_vae_history))
        capture_generation(f"cycle {cycle}: after VAE warm-up", cycle)

        if rebuild_cache_each_cycle or cycle == 1:
            print(f"Rebuilding the cache after cycle {cycle} VAE warm-up...")
            cache_start = time.perf_counter()
            DRIFT_CACHE = build_conditional_drift_cache(
                model, train_loader, NUM_CLASSES, num_landmarks, T
            )
            print(
                f"Cycle {cycle} cache built in "
                f"{(time.perf_counter() - cache_start) / 60:.2f} minutes"
            )

        cycle_generator_history = warmup_generator(
            model, train_loader, epochs=cycle_generator_epochs, lr=generator_lr
        )
        phase_history.append((f"cycle {cycle}: latent generator warm-up", cycle_generator_history))
        capture_generation(f"cycle {cycle}: after latent generator warm-up", cycle)

        cycle_drift_history = warmup_generator_drift(
            model,
            train_loader,
            epochs=cycle_drift_epochs,
            cache=DRIFT_CACHE,
            T=T,
            lambda_drift=lambda_drift,
            raw_drift_weight=raw_drift_weight,
            lr=generator_drift_lr,
        )
        phase_history.append((f"cycle {cycle}: DriftXpress warm-up", cycle_drift_history))
        capture_generation(f"cycle {cycle}: after DriftXpress warm-up", cycle)

        cycle_joint_history = run_joint_phase(
            model,
            train_loader,
            cycle_joint_epochs,
            T,
            DRIFT_CACHE,
            lambda_kl,
            lambda_drift,
            lambda_var,
            lambda_cov,
            lambda_representation,
            loss_scale,
            joint_generator_lr,
            joint_vae_lr,
            raw_drift_weight,
            cycle,
            evolution,
        )
        phase_history.append((f"cycle {cycle}: fully joint training", cycle_joint_history))
        capture_generation(f"cycle {cycle}: after fully joint training", cycle)
        for key in combined_joint_history:
            combined_joint_history[key].extend(cycle_joint_history[key])

        cycle_records.append({
            "cycle": cycle,
            "vae": cycle_vae_history,
            "generator": cycle_generator_history,
            "drift": cycle_drift_history,
            "joint": cycle_joint_history,
        })

    print("Finished repeated warm-up and joint training.")
    return (
        model,
        combined_joint_history["total"],
        combined_joint_history["recon"],
        combined_joint_history["kl"],
        combined_joint_history["drift"],
        combined_joint_history["var"],
        combined_joint_history["covar"],
        combined_joint_history["force"],
        evolution,
        initial_vae_history,
        phase_history,
        cycle_records,
        combined_joint_history["drift_raw"],
        generation_evolution,
    )

# %%
# Cyclic version of the pretrained fully joint experiment.
# The model, losses, conditional MNIST setup, and DriftXpress implementation
# remain the same as in pretrained-full-joint.ipynb.
NUM_CLASSES = 6
LATENT_DIM = 32

INITIAL_VAE_PRETRAIN_EPOCHS = 50
NUM_CYCLES = 3
CYCLE_VAE_EPOCHS = 10
CYCLE_GENERATOR_EPOCHS = 10
CYCLE_DRIFT_EPOCHS = 10
CYCLE_JOINT_EPOCHS = 50

NUM_LANDMARKS = 200
TEMPERATURE = 2
LAMBDA_KL = 1e-5
LAMBDA_DRIFT = 30.0
LAMBDA_VAR = 0.1
LAMBDA_COV = 0.3
LAMBDA_REPRESENTATION = 1.0
LOSS_SCALE = 1.0

(
    f_trained,
    losses,
    recon_losses,
    kl_losses,
    drift_losses,
    var_losses,
    covar_losses,
    average_V,
    evolution,
    initial_vae_history,
    phase_history,
    cycle_records,
    drift_raw_losses,
    generation_evolution,
) = cyclic_training_loop(
    initial_vae_epochs=INITIAL_VAE_PRETRAIN_EPOCHS,
    num_cycles=NUM_CYCLES,
    cycle_vae_epochs=CYCLE_VAE_EPOCHS,
    cycle_generator_epochs=CYCLE_GENERATOR_EPOCHS,
    cycle_drift_epochs=CYCLE_DRIFT_EPOCHS,
    cycle_joint_epochs=CYCLE_JOINT_EPOCHS,
    T=TEMPERATURE,
    num_landmarks=NUM_LANDMARKS,
    lambda_kl=LAMBDA_KL,
    lambda_drift=LAMBDA_DRIFT,
    lambda_var=LAMBDA_VAR,
    lambda_cov=LAMBDA_COV,
    lambda_representation=LAMBDA_REPRESENTATION,
    loss_scale=LOSS_SCALE,
    vae_lr=1e-4,
    generator_lr=1e-3,
    generator_drift_lr=1e-4,
    joint_generator_lr=1e-4,
    joint_vae_lr=1e-5,
    raw_drift_weight=0.25,
    rebuild_cache_each_cycle=True,
)
# Out:
# Pretraining the VAE part for 50 epochs (generator frozen)...
# -------- VAE pretrain epoch 1/50 --------
# total=0.342867
# representation=0.342867    scaled=0.342867
# recon=0.203310    scaled=0.203310
# kl=2.649730    scaled=0.000026
# var=1.366076    scaled=0.136608
# covar=0.009742    scaled=0.002923
# -------- VAE pretrain epoch 5/50 --------
# total=0.195230
# representation=0.195230    scaled=0.195230
# recon=0.069284    scaled=0.069284
# kl=17.195512    scaled=0.000172
# var=1.171460    scaled=0.117146
# covar=0.028763    scaled=0.008629
# -------- VAE pretrain epoch 10/50 --------
# total=0.172359
# representation=0.172359    scaled=0.172359
# recon=0.057052    scaled=0.057052
# kl=36.116441    scaled=0.000361
# var=1.031873    scaled=0.103187
# covar=0.039195    scaled=0.011759
# -------- VAE pretrain epoch 15/50 --------
# total=0.145681
# representation=0.145681    scaled=0.145681
# recon=0.039914    scaled=0.039914
# kl=81.644120    scaled=0.000816
# var=0.928108    scaled=0.092811
# covar=0.040469    scaled=0.012141
# -------- VAE pretrain epoch 20/50 --------
# total=0.134019
# representation=0.134019    scaled=0.134019
# recon=0.033115    scaled=0.033115
# kl=101.880963    scaled=0.001019
# var=0.870121    scaled=0.087012
# covar=0.042910    scaled=0.012873
# -------- VAE pretrain epoch 25/50 --------
# total=0.125886
# representation=0.125886    scaled=0.125886
# recon=0.028043    scaled=0.028043
# kl=111.533842    scaled=0.001115
# var=0.827978    scaled=0.082798
# covar=0.046434    scaled=0.013930
# -------- VAE pretrain epoch 30/50 --------
# total=0.121574
# representation=0.121574    scaled=0.121574
# recon=0.024751    scaled=0.024751
# kl=117.690828    scaled=0.001177
# var=0.808857    scaled=0.080886
# covar=0.049201    scaled=0.014760
# -------- VAE pretrain epoch 35/50 --------
# total=0.117646
# representation=0.117646    scaled=0.117646
# recon=0.022745    scaled=0.022745
# kl=123.337837    scaled=0.001233
# var=0.788414    scaled=0.078841
# covar=0.049423    scaled=0.014827
# -------- VAE pretrain epoch 40/50 --------
# total=0.115494
# representation=0.115494    scaled=0.115494
# recon=0.021407    scaled=0.021407
# kl=127.123179    scaled=0.001271
# var=0.770162    scaled=0.077016
# covar=0.052663    scaled=0.015799
# -------- VAE pretrain epoch 45/50 --------
# total=0.113173
# representation=0.113173    scaled=0.113173
# recon=0.020524    scaled=0.020524
# kl=127.900040    scaled=0.001279
# var=0.753389    scaled=0.075339
# covar=0.053437    scaled=0.016031
# -------- VAE pretrain epoch 50/50 --------
# total=0.111150
# representation=0.111150    scaled=0.111150
# recon=0.019860    scaled=0.019860
# kl=128.284454    scaled=0.001283
# var=0.731694    scaled=0.073169
# covar=0.056126    scaled=0.016838
# Building the initial conditional DriftXpress cache...
# Initial cache built in 0.13 minutes
#
# ================ CYCLE 1/3 ================
# Pretraining the VAE part for 10 epochs (generator frozen)...
# -------- VAE pretrain epoch 1/10 --------
# total=0.111236
# representation=0.111236    scaled=0.111236
# recon=0.019762    scaled=0.019762
# kl=127.989161    scaled=0.001280
# var=0.726750    scaled=0.072675
# covar=0.058397    scaled=0.017519
# -------- VAE pretrain epoch 5/10 --------
# total=0.109246
# representation=0.109246    scaled=0.109246
# recon=0.019194    scaled=0.019194
# kl=127.192578    scaled=0.001272
# var=0.713578    scaled=0.071358
# covar=0.058073    scaled=0.017422
# -------- VAE pretrain epoch 10/10 --------
# total=0.107384
# representation=0.107384    scaled=0.107384
# recon=0.018653    scaled=0.018653
# kl=126.596207    scaled=0.001266
# var=0.693767    scaled=0.069377
# covar=0.060293    scaled=0.018088
# Rebuilding the cache after cycle 1 VAE warm-up...
# Cycle 1 cache built in 0.13 minutes
# Warming up the generator for 10 epochs (VAE frozen)...
# -------- Generator warmup epoch 1/10 --------
# latent_match=1.658770
# -------- Generator warmup epoch 5/10 --------
# latent_match=0.761437
# -------- Generator warmup epoch 10/10 --------
# latent_match=0.758264
# Warming up the generator with DriftXpress for 10 epochs (VAE frozen)...
# -------- Generator DriftXpress warmup epoch 1/10 --------
# drift=0.021230 raw_drift=0.014144 total=0.742992 average |V|=0.800446
# -------- Generator DriftXpress warmup epoch 5/10 --------
# drift=0.007386 raw_drift=0.026242 total=0.418400 average |V|=0.470784
# -------- Generator DriftXpress warmup epoch 10/10 --------
# drift=0.007251 raw_drift=0.025837 total=0.411317 average |V|=0.465838
# Cycle 1: fully joint training for 50 epochs (generator lr=0.0001, VAE lr=1e-05)
# -------- Cycle 1, joint epoch 0 --------
# total=0.479264
# representation=0.274749    scaled=0.274749
# recon=0.019081    scaled=0.019081
# kl=129.329687    scaled=0.001293
# drift=0.006817    scaled=0.204516
# var=1.846429    scaled=0.184643
# covar=0.232439    scaled=0.069732
# reencoded drift=0.002277 raw drift=0.018159
# distances 7.182737350463867
# average |V|=0.254860
# latent std positive=0.808314
# latent std negative=0.339239
# -------- Cycle 1, joint epoch 1 --------
# total=0.375601
# representation=0.272241    scaled=0.272241
# recon=0.020096    scaled=0.020096
# kl=130.364694    scaled=0.001304
# drift=0.003445    scaled=0.103360
# var=1.854112    scaled=0.185411
# covar=0.218100    scaled=0.065430
# reencoded drift=0.000950 raw drift=0.009982
# distances 7.101639747619629
# average |V|=0.168093
# latent std positive=0.807492
# latent std negative=0.341845
# -------- Cycle 1, joint epoch 2 --------
# total=0.347564
# representation=0.271887    scaled=0.271887
# recon=0.020496    scaled=0.020496
# kl=130.006433    scaled=0.001300
# drift=0.002523    scaled=0.075677
# var=1.856534    scaled=0.185653
# covar=0.214792    scaled=0.064438
# reencoded drift=0.000774 raw drift=0.006996
# distances 7.189693450927734
# average |V|=0.150400
# latent std positive=0.793150
# latent std negative=0.334666
# -------- Cycle 1, joint epoch 3 --------
# total=0.332310
# representation=0.271987    scaled=0.271987
# recon=0.020705    scaled=0.020705
# kl=129.536203    scaled=0.001295
# drift=0.002011    scaled=0.060323
# var=1.858660    scaled=0.185866
# covar=0.213735    scaled=0.064120
# reencoded drift=0.000752 raw drift=0.005033
# distances 7.254321575164795
# average |V|=0.147827
# latent std positive=0.797430
# latent std negative=0.339923
# -------- Cycle 1, joint epoch 4 --------
# total=0.323806
# representation=0.272001    scaled=0.272001
# recon=0.020898    scaled=0.020898
# kl=128.976422    scaled=0.001290
# drift=0.001727    scaled=0.051806
# var=1.860091    scaled=0.186009
# covar=0.212680    scaled=0.063804
# reencoded drift=0.000767 raw drift=0.003839
# distances 6.849102020263672
# average |V|=0.148174
# latent std positive=0.805874
# latent std negative=0.338512
# -------- Cycle 1, joint epoch 10 --------
# total=0.323226
# representation=0.271622    scaled=0.271622
# recon=0.022633    scaled=0.022633
# kl=126.529184    scaled=0.001265
# drift=0.001720    scaled=0.051604
# var=1.853302    scaled=0.185330
# covar=0.207980    scaled=0.062394
# reencoded drift=0.001264 raw drift=0.001823
# distances 7.631481170654297
# average |V|=0.188627
# latent std positive=0.798027
# latent std negative=0.357970
# -------- Cycle 1, joint epoch 20 --------
# total=0.365991
# representation=0.271470    scaled=0.271470
# recon=0.027018    scaled=0.027018
# kl=125.345133    scaled=0.001253
# drift=0.003151    scaled=0.094521
# var=1.800209    scaled=0.180021
# covar=0.210593    scaled=0.063178
# reencoded drift=0.002455 raw drift=0.002782
# distances 7.533237457275391
# average |V|=0.264405
# latent std positive=0.806870
# latent std negative=0.395759
# -------- Cycle 1, joint epoch 30 --------
# total=0.377526
# representation=0.269859    scaled=0.269859
# recon=0.028898    scaled=0.028898
# kl=124.647950    scaled=0.001246
# drift=0.003589    scaled=0.107667
# var=1.766341    scaled=0.176634
# covar=0.210266    scaled=0.063080
# reencoded drift=0.002819 raw drift=0.003080
# distances 7.596003532409668
# average |V|=0.284843
# latent std positive=0.815111
# latent std negative=0.436383
# -------- Cycle 1, joint epoch 40 --------
# total=0.387626
# representation=0.266747    scaled=0.266747
# recon=0.029792    scaled=0.029792
# kl=124.606629    scaled=0.001246
# drift=0.004029    scaled=0.120879
# var=1.743293    scaled=0.174329
# covar=0.204599    scaled=0.061380
# reencoded drift=0.003239 raw drift=0.003160
# distances 7.40485143661499
# average |V|=0.307177
# latent std positive=0.813060
# latent std negative=0.451991
# -------- Cycle 1, joint epoch 50 --------
# total=0.398366
# representation=0.262703    scaled=0.262703
# recon=0.030363    scaled=0.030363
# kl=124.706734    scaled=0.001247
# drift=0.004522    scaled=0.135662
# var=1.716905    scaled=0.171691
# covar=0.198009    scaled=0.059403
# reencoded drift=0.003652 raw drift=0.003480
# distances 7.463921546936035
# average |V|=0.324801
# latent std positive=0.826852
# latent std negative=0.471456
#
# ================ CYCLE 2/3 ================
# Pretraining the VAE part for 10 epochs (generator frozen)...
# -------- VAE pretrain epoch 1/10 --------
# total=0.111885
# representation=0.111885    scaled=0.111885
# recon=0.020977    scaled=0.020977
# kl=125.618956    scaled=0.001256
# var=0.698129    scaled=0.069813
# covar=0.066130    scaled=0.019839
# -------- VAE pretrain epoch 5/10 --------
# total=0.106564
# representation=0.106564    scaled=0.106564
# recon=0.018582    scaled=0.018582
# kl=125.944097    scaled=0.001259
# var=0.680061    scaled=0.068006
# covar=0.062387    scaled=0.018716
# -------- VAE pretrain epoch 10/10 --------
# total=0.106125
# representation=0.106125    scaled=0.106125
# recon=0.018192    scaled=0.018192
# kl=124.812857    scaled=0.001248
# var=0.667242    scaled=0.066724
# covar=0.066536    scaled=0.019961
# Rebuilding the cache after cycle 2 VAE warm-up...
# Cycle 2 cache built in 0.11 minutes
# Warming up the generator for 10 epochs (VAE frozen)...
# -------- Generator warmup epoch 1/10 --------
# latent_match=0.825108
# -------- Generator warmup epoch 5/10 --------
# latent_match=0.796246
# -------- Generator warmup epoch 10/10 --------
# latent_match=0.795423
# Warming up the generator with DriftXpress for 10 epochs (VAE frozen)...
# -------- Generator DriftXpress warmup epoch 1/10 --------
# drift=0.021541 raw_drift=0.012621 total=0.740883 average |V|=0.803823
# -------- Generator DriftXpress warmup epoch 5/10 --------
# drift=0.006283 raw_drift=0.026262 total=0.385471 average |V|=0.439549
# -------- Generator DriftXpress warmup epoch 10/10 --------
# drift=0.007653 raw_drift=0.026963 total=0.431795 average |V|=0.454302
# Cycle 2: fully joint training for 50 epochs (generator lr=0.0001, VAE lr=1e-05)
# -------- Cycle 2, joint epoch 0 --------
# total=0.518975
# representation=0.261678    scaled=0.261678
# recon=0.018565    scaled=0.018565
# kl=127.286039    scaled=0.001273
# drift=0.008577    scaled=0.257297
# var=1.789790    scaled=0.178979
# covar=0.209536    scaled=0.062861
# reencoded drift=0.003570 raw drift=0.020028
# distances 7.414960861206055
# average |V|=0.288585
# latent std positive=0.829001
# latent std negative=0.373558
# -------- Cycle 2, joint epoch 1 --------
# total=0.409285
# representation=0.258431    scaled=0.258431
# recon=0.019539    scaled=0.019539
# kl=127.491531    scaled=0.001275
# drift=0.005028    scaled=0.150855
# var=1.790227    scaled=0.179023
# covar=0.195312    scaled=0.058594
# reencoded drift=0.002008 raw drift=0.012083
# distances 7.694090366363525
# average |V|=0.227022
# latent std positive=0.836046
# latent std negative=0.372301
# -------- Cycle 2, joint epoch 2 --------
# total=0.383640
# representation=0.258622    scaled=0.258622
# recon=0.020283    scaled=0.020283
# kl=127.027748    scaled=0.001270
# drift=0.004167    scaled=0.125018
# var=1.786079    scaled=0.178608
# covar=0.194868    scaled=0.058460
# reencoded drift=0.001963 raw drift=0.008818
# distances 7.605437278747559
# average |V|=0.221058
# latent std positive=0.838099
# latent std negative=0.390775
# -------- Cycle 2, joint epoch 3 --------
# total=0.366351
# representation=0.259847    scaled=0.259847
# recon=0.020930    scaled=0.020930
# kl=126.549486    scaled=0.001265
# drift=0.003550    scaled=0.106505
# var=1.782470    scaled=0.178247
# covar=0.198013    scaled=0.059404
# reencoded drift=0.001857 raw drift=0.006771
# distances 7.5021796226501465
# average |V|=0.220935
# latent std positive=0.833243
# latent std negative=0.387390
# -------- Cycle 2, joint epoch 4 --------
# total=0.355832
# representation=0.259177    scaled=0.259177
# recon=0.021484    scaled=0.021484
# kl=126.231896    scaled=0.001262
# drift=0.003222    scaled=0.096656
# var=1.778212    scaled=0.177821
# covar=0.195364    scaled=0.058609
# reencoded drift=0.001864 raw drift=0.005432
# distances 7.2375078201293945
# average |V|=0.220645
# latent std positive=0.821978
# latent std negative=0.396903
# -------- Cycle 2, joint epoch 10 --------
# total=0.347886
# representation=0.260080    scaled=0.260080
# recon=0.023959    scaled=0.023959
# kl=125.204372    scaled=0.001252
# drift=0.002927    scaled=0.087806
# var=1.757591    scaled=0.175759
# covar=0.197035    scaled=0.059111
# reencoded drift=0.002191 raw drift=0.002942
# distances 7.777795314788818
# average |V|=0.236749
# latent std positive=0.836779
# latent std negative=0.428287
# -------- Cycle 2, joint epoch 20 --------
# total=0.352673
# representation=0.257733    scaled=0.257733
# recon=0.025959    scaled=0.025959
# kl=124.339696    scaled=0.001243
# drift=0.003165    scaled=0.094940
# var=1.729730    scaled=0.172973
# covar=0.191860    scaled=0.057558
# reencoded drift=0.002490 raw drift=0.002697
# distances 7.58088493347168
# average |V|=0.261463
# latent std positive=0.835900
# latent std negative=0.469956
# -------- Cycle 2, joint epoch 30 --------
# total=0.370262
# representation=0.254967    scaled=0.254967
# recon=0.026714    scaled=0.026714
# kl=124.522488    scaled=0.001245
# drift=0.003843    scaled=0.115295
# var=1.705245    scaled=0.170524
# covar=0.188279    scaled=0.056484
# reencoded drift=0.003093 raw drift=0.002999
# distances 7.556005477905273
# average |V|=0.282439
# latent std positive=0.828723
# latent std negative=0.471740
# -------- Cycle 2, joint epoch 40 --------
# total=0.372472
# representation=0.252144    scaled=0.252144
# recon=0.026878    scaled=0.026878
# kl=124.933841    scaled=0.001249
# drift=0.004011    scaled=0.120328
# var=1.687188    scaled=0.168719
# covar=0.184328    scaled=0.055299
# reencoded drift=0.003204 raw drift=0.003229
# distances 7.590357780456543
# average |V|=0.296904
# latent std positive=0.843089
# latent std negative=0.488878
# -------- Cycle 2, joint epoch 50 --------
# total=0.382898
# representation=0.248457    scaled=0.248457
# recon=0.026847    scaled=0.026847
# kl=125.181384    scaled=0.001252
# drift=0.004481    scaled=0.134441
# var=1.672876    scaled=0.167288
# covar=0.176903    scaled=0.053071
# reencoded drift=0.003641 raw drift=0.003361
# distances 7.823802947998047
# average |V|=0.310996
# latent std positive=0.833436
# latent std negative=0.508613
#
# ================ CYCLE 3/3 ================
# Pretraining the VAE part for 10 epochs (generator frozen)...
# -------- VAE pretrain epoch 1/10 --------
# total=0.108594
# representation=0.108594    scaled=0.108594
# recon=0.019755    scaled=0.019755
# kl=123.944127    scaled=0.001239
# var=0.675173    scaled=0.067517
# covar=0.066942    scaled=0.020083
# -------- VAE pretrain epoch 5/10 --------
# total=0.105456
# representation=0.105456    scaled=0.105456
# recon=0.018120    scaled=0.018120
# kl=123.493534    scaled=0.001235
# var=0.662156    scaled=0.066216
# covar=0.066284    scaled=0.019885
# -------- VAE pretrain epoch 10/10 --------
# total=0.104675
# representation=0.104675    scaled=0.104675
# recon=0.017699    scaled=0.017699
# kl=123.336519    scaled=0.001233
# var=0.652456    scaled=0.065246
# covar=0.068323    scaled=0.020497
# Rebuilding the cache after cycle 3 VAE warm-up...
# Cycle 3 cache built in 0.10 minutes
# Warming up the generator for 10 epochs (VAE frozen)...
# -------- Generator warmup epoch 1/10 --------
# latent_match=0.846729
# -------- Generator warmup epoch 5/10 --------
# latent_match=0.820884
# -------- Generator warmup epoch 10/10 --------
# latent_match=0.820676
# Warming up the generator with DriftXpress for 10 epochs (VAE frozen)...
# -------- Generator DriftXpress warmup epoch 1/10 --------
# drift=0.025445 raw_drift=0.012270 total=0.855362 average |V|=0.867033
# -------- Generator DriftXpress warmup epoch 5/10 --------
# drift=0.006099 raw_drift=0.027996 total=0.392940 average |V|=0.434362
# -------- Generator DriftXpress warmup epoch 10/10 --------
# drift=0.006832 raw_drift=0.026250 total=0.401838 average |V|=0.446494
# Cycle 3: fully joint training for 50 epochs (generator lr=0.0001, VAE lr=1e-05)
# -------- Cycle 3, joint epoch 0 --------
# total=0.528805
# representation=0.253972    scaled=0.253972
# recon=0.017961    scaled=0.017961
# kl=125.603087    scaled=0.001256
# drift=0.009161    scaled=0.274833
# var=1.734119    scaled=0.173412
# covar=0.204477    scaled=0.061343
# reencoded drift=0.004093 raw drift=0.020274
# distances 7.413760662078857
# average |V|=0.310210
# latent std positive=0.852701
# latent std negative=0.405535
# -------- Cycle 3, joint epoch 1 --------
# total=0.415862
# representation=0.251785    scaled=0.251785
# recon=0.018679    scaled=0.018679
# kl=125.831649    scaled=0.001258
# drift=0.005469    scaled=0.164077
# var=1.738390    scaled=0.173839
# covar=0.193362    scaled=0.058009
# reencoded drift=0.002370 raw drift=0.012396
# distances 7.789481163024902
# average |V|=0.254076
# latent std positive=0.862821
# latent std negative=0.415100
# -------- Cycle 3, joint epoch 2 --------
# total=0.388569
# representation=0.250602    scaled=0.250602
# recon=0.019289    scaled=0.019289
# kl=125.535563    scaled=0.001255
# drift=0.004599    scaled=0.137968
# var=1.733698    scaled=0.173370
# covar=0.188959    scaled=0.056688
# reencoded drift=0.002311 raw drift=0.009150
# distances 7.274415493011475
# average |V|=0.248693
# latent std positive=0.845895
# latent std negative=0.417837
# -------- Cycle 3, joint epoch 3 --------
# total=0.378004
# representation=0.250956    scaled=0.250956
# recon=0.019847    scaled=0.019847
# kl=125.163365    scaled=0.001252
# drift=0.004235    scaled=0.127048
# var=1.729942    scaled=0.172994
# covar=0.189546    scaled=0.056864
# reencoded drift=0.002409 raw drift=0.007303
# distances 7.6579437255859375
# average |V|=0.253533
# latent std positive=0.851455
# latent std negative=0.417984
# -------- Cycle 3, joint epoch 4 --------
# total=0.373592
# representation=0.250593    scaled=0.250593
# recon=0.020310    scaled=0.020310
# kl=124.879287    scaled=0.001249
# drift=0.004100    scaled=0.122999
# var=1.724761    scaled=0.172476
# covar=0.188526    scaled=0.056558
# reencoded drift=0.002562 raw drift=0.006151
# distances 7.592454433441162
# average |V|=0.255203
# latent std positive=0.851754
# latent std negative=0.423779
# -------- Cycle 3, joint epoch 10 --------
# total=0.358695
# representation=0.249949    scaled=0.249949
# recon=0.022459    scaled=0.022459
# kl=124.169218    scaled=0.001242
# drift=0.003625    scaled=0.108746
# var=1.699850    scaled=0.169985
# covar=0.187544    scaled=0.056263
# reencoded drift=0.002680 raw drift=0.003780
# distances 7.683640480041504
# average |V|=0.265586
# latent std positive=0.844088
# latent std negative=0.445111
# -------- Cycle 3, joint epoch 20 --------
# total=0.365095
# representation=0.246751    scaled=0.246751
# recon=0.023636    scaled=0.023636
# kl=124.457699    scaled=0.001245
# drift=0.003945    scaled=0.118344
# var=1.673668    scaled=0.167367
# covar=0.181677    scaled=0.054503
# reencoded drift=0.003077 raw drift=0.003471
# distances 7.625155925750732
# average |V|=0.285912
# latent std positive=0.832930
# latent std negative=0.478149
# -------- Cycle 3, joint epoch 30 --------
# total=0.373022
# representation=0.243387    scaled=0.243387
# recon=0.024057    scaled=0.024057
# kl=124.317795    scaled=0.001243
# drift=0.004321    scaled=0.129635
# var=1.662182    scaled=0.166218
# covar=0.172898    scaled=0.051869
# reencoded drift=0.003486 raw drift=0.003339
# distances 7.720905303955078
# average |V|=0.291728
# latent std positive=0.864730
# latent std negative=0.495975
# -------- Cycle 3, joint epoch 40 --------
# total=0.367128
# representation=0.240534    scaled=0.240534
# recon=0.024238    scaled=0.024238
# kl=124.226083    scaled=0.001242
# drift=0.004220    scaled=0.126594
# var=1.650225    scaled=0.165023
# covar=0.166771    scaled=0.050031
# reencoded drift=0.003389 raw drift=0.003324
# distances 7.847790241241455
# average |V|=0.304623
# latent std positive=0.846813
# latent std negative=0.507694
# -------- Cycle 3, joint epoch 50 --------
# total=0.371912
# representation=0.237951    scaled=0.237951
# recon=0.024416    scaled=0.024416
# kl=123.947329    scaled=0.001239
# drift=0.004465    scaled=0.133961
# var=1.643786    scaled=0.164379
# covar=0.159721    scaled=0.047916
# reencoded drift=0.003612 raw drift=0.003413
# distances 7.786988258361816
# average |V|=0.313601
# latent std positive=0.847406
# latent std negative=0.504808
# Finished repeated warm-up and joint training.

# %%
# Optional: inspect the actual weighted gradient paths before calling backward.
f_trained.train()
images, class_ids = next(iter(train_loader))
x = images.to(device).flatten(start_dim=1)
class_ids = class_ids.to(device)
noise = torch.randn(x.shape[0], f_trained.latent_dim, device=device)
mu, logvar, z_pos = f_trained.get_latent(x)
x_recon = f_trained.decode(z_pos)
z_raw, x_neg = f_trained.generate(noise, class_ids)
z_neg = f_trained.encode_mu(x_neg)
L_recon = recon_loss(x_recon, x)
L_drift_reencoded, _ = conditional_drift_loss(z_neg, class_ids, DRIFT_CACHE, TEMPERATURE)
L_drift_raw, _ = conditional_drift_loss(z_raw, class_ids, DRIFT_CACHE, TEMPERATURE)
L_drift = L_drift_reencoded + 0.25 * L_drift_raw
print(per_loss_gradient_norms(
    {"recon": L_recon, "drift": L_drift},
    f_trained,
    {"drift": LAMBDA_DRIFT},
    lambda_representation=LAMBDA_REPRESENTATION,
))
# Out:
# {'recon': {'encoder': {'total_norm': 0.04932839634083081, 'nonzero_parameters': 8, 'parameter_count': 8}, 'decoder': {'total_norm': 0.03478607535537536, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 0.0, 'nonzero_parameters': 0, 'parameter_count': 9}}, 'drift': {'encoder': {'total_norm': 5.629883564801604, 'nonzero_parameters': 6, 'parameter_count': 8}, 'decoder': {'total_norm': 4.021704974045279, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 4.3841857143262635, 'nonzero_parameters': 9, 'parameter_count': 9}}, 'total': {'encoder': {'total_norm': 5.624656954187463, 'nonzero_parameters': 8, 'parameter_count': 8}, 'decoder': {'total_norm': 4.021370764559297, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 4.3841857143262635, 'nonzero_parameters': 9, 'parameter_count': 9}}}

# %%
joint_history = {
    "total": losses,
    "recon": recon_losses,
    "kl": kl_losses,
    "drift": drift_losses,
    "drift_raw": drift_raw_losses,
    "var": var_losses,
    "covar": covar_losses,
    "force": average_V,
}


def plot_repeated_training_phases(phase_history):
    """Plot all VAE, generator, DriftXpress, and joint phases in order."""
    keys = ("total", "recon", "kl", "drift", "drift_raw", "var", "covar", "force", "latent_match")
    figure, axes = plt.subplots(5, 2, figsize=(16, 22), sharex=False)
    axes = axes.ravel()
    boundaries = []
    offset = 0

    for phase_name, history in phase_history:
        phase_length = len(history.get("total", []))
        boundaries.append((offset, offset + phase_length, phase_name))
        offset += phase_length

    for axis, key in zip(axes, keys):
        offset = 0
        plotted = False
        for phase_name, history in phase_history:
            values = np.asarray(history.get(key, []), dtype=float)
            if values.size:
                x_values = np.arange(offset, offset + values.size)
                axis.plot(x_values, values, label=phase_name)
                plotted = True
            offset += len(history.get("total", []))
        if plotted:
            axis.set_title(key)
            axis.set_yscale("log")
            axis.grid(alpha=0.25)
            axis.legend(fontsize=7)
        else:
            axis.axis("off")

    for _, end, _ in boundaries[:-1]:
        for axis in axes:
            axis.axvline(end - 0.5, color="black", linestyle="--", alpha=0.25)
    axes[-1].axis("off")
    figure.suptitle(
        "Repeated VAE warm-up → generator warm-up → DriftXpress warm-up → joint training"
    )
    figure.tight_layout()
    return figure, axes


fig, axes = plot_repeated_training_phases(phase_history)
plt.show()

# %%
def plot_generation_evolution(generation_evolution):
    """Show fixed-noise generations at the end of every training phase."""
    if not generation_evolution:
        raise ValueError("generation_evolution is empty")

    n_rows = len(generation_evolution)
    n_cols = generation_evolution[0]["images"].shape[0]
    figure, axes = plt.subplots(
        n_rows,
        n_cols,
        figsize=(2.0 * n_cols, 1.55 * n_rows),
        squeeze=False,
    )
    digits = CLASS_TO_DIGIT[generation_evolution[0]["class_ids"]]

    for row, record in enumerate(generation_evolution):
        for column in range(n_cols):
            axis = axes[row, column]
            axis.imshow(record["images"][column, 0], cmap="gray", vmin=0, vmax=1)
            axis.axis("off")
            if row == 0:
                axis.set_title(str(int(digits[column])))
        axes[row, 0].set_ylabel(
            record["stage"],
            rotation=0,
            ha="right",
            va="center",
            fontsize=8,
            labelpad=12,
        )

    figure.suptitle("Generation at the end of each cyclic training phase")
    figure.tight_layout()
    return figure, axes


fig_generation, axes_generation = plot_generation_evolution(generation_evolution)
plt.show()

# %%
import importlib
import src.eval as eval_utils

importlib.reload(eval_utils)

from src.eval import evaluate_latent_model

# %%
# One reusable post-training call: it collects real encoder means and
# conditional generated latents/images, then computes latent SWD/FID and class metrics.
post_eval = evaluate_latent_model(
    f_trained,
    test_loader,
    device=device,
    n_samples=2048,
    n_classes=NUM_CLASSES,
    class_to_label=CLASS_TO_DIGIT,
    include_mmd=False,
    include_fid=True,
)

samples = post_eval["samples"]
real_latents = samples["real_latents"]
generated_latents = samples["generated_latents"]
real_pixels = samples["real_images"]
generated_pixels = samples["generated_images"]
real_class_labels = samples["real_class_ids"]
generated_class_labels = samples["generated_class_ids"]
real_labels = samples["real_labels"]
generated_labels = samples["generated_labels"]
metrics = post_eval["metrics"]
latent_stats = post_eval["statistics"]

print("Latent-space metrics:")
for name, value in metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent-space metrics:
# sliced_wasserstein: 0.382927
# fid: 13.782514
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
import sys
import inspect

project_root = r"C:\Users\mateo\Desktop\polymath-jr-drifting"

if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Remove stale src modules without restarting the kernel.
for name in list(sys.modules):
    if name == "src" or name.startswith("src."):
        del sys.modules[name]

import src.eval as eval_utils

print(eval_utils.__file__)
print(inspect.signature(eval_utils.evaluate_generation))

from src.eval import evaluate_latent_model, evaluate_generation
# Out:
# C:\Users\mateo\Desktop\polymath-jr-drifting\src\eval.py
# (real_features: 'Any', generated_features: 'Any', generated_labels: 'Any | None' = None, n_classes: 'int | None' = None, coverage_min_count: 'int' = 1, random_state: 'int | None' = 0, n_projections: 'int' = 128, mmd_max_samples: 'int | None' = 2048, include_mmd: 'bool' = True, include_fid: 'bool' = True) -> 'dict[str, float]'

# %%
# This is the same compact metric interface in pixel space.
# Its FID is a pixel-space Fréchet distance; use evaluate_mnist_generation with a
# frozen evaluator when you specifically want learned MNIST-feature FID.
pixel_metrics = evaluate_generation(
    real_pixels,
    generated_pixels,
    generated_labels=generated_class_labels,
    n_classes=NUM_CLASSES,
    include_mmd=False,
)
print("Pixel-space metrics:")
for name, value in pixel_metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Pixel-space metrics:
# sliced_wasserstein: 0.093927
# fid: 26.622004
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
print("Latent statistics:")
for name, value in latent_stats.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent statistics:
# real_latent_mean: -0.060202
# generated_latent_mean: -0.071670
# real_latent_std: 0.812601
# generated_latent_std: 0.431284
# generated_to_real_std_ratio: 0.530745
# real_total_correlation: 12.713060
# generated_total_correlation: 30.675878

# %%
fig, axes = plot_conditional_mnist_results(
    f_trained,
    test_loader,
    device=device,
    samples=10,
    use_mean_for_reconstruction=True,
)
plt.show()

# %%
with torch.no_grad():
    generated_images_tensor = torch.as_tensor(
        generated_pixels, dtype=torch.float32, device=device
    )
    generated_reencoded = f_trained.encode_mu(generated_images_tensor).cpu().numpy()

reencoded_stats = latent_statistics(real_latents, generated_reencoded)
print(reencoded_stats)

plot_real_generated_projections(
    real_latents,
    generated_reencoded,
    real_labels=real_labels,
    generated_labels=generated_labels,
    methods=("pca", "umap"),
)
plt.show()
# Out:
# {'real_latent_mean': -0.06020224693864051, 'generated_latent_mean': -0.06548294303430247, 'real_latent_std': 0.8126007832204408, 'generated_latent_std': 0.515195486332332, 'generated_to_real_std_ratio': 0.6340081094809513, 'real_total_correlation': 12.713059688143613, 'generated_total_correlation': 19.07214537437752}
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# Within each cycle, the attraction summaries are precomputed once and reused for the complete generator and joint phases.
#
# "
#     "After the short VAE warm-up changes the encoder, the summaries are rebuilt once at the next cycle boundary so the following phases use the current latent coordinates.
