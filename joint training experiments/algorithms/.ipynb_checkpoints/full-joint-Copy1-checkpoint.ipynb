# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms, utils
from torch.utils.data import DataLoader
# %cd "C:/Users/mateo/Desktop/polymath-jr-drifting"
# This notebook uses DriftXpress; exact drift uses its separate loss/cache API in src.drift.
from src.driftXpress import *
from src.eval import *
from src.training import (
    compose_objective,
    format_epoch_losses,
    gradient_report,
    per_loss_gradient_norms,
    set_requires_grad,
)
torch.manual_seed(7)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# C:\Users\mateo\Desktop\polymath-jr-drifting
# Using: cuda

# %%
transform = transforms.ToTensor()

SELECTED_DIGITS = (0, 8, 2, 4, 7, 9)
DIGIT_TO_CLASS = {digit: index for index, digit in enumerate(SELECTED_DIGITS)}
CLASS_TO_DIGIT = np.asarray(SELECTED_DIGITS)

train_data = datasets.MNIST("data", train=True, download=True, transform=transform)
test_data = datasets.MNIST("data", train=False, download=True, transform=transform)

def keep_selected_digits(dataset):
    selected = torch.tensor(SELECTED_DIGITS, dtype=dataset.targets.dtype)
    mask = torch.isin(dataset.targets, selected)
    dataset.data = dataset.data[mask]
    raw_targets = dataset.targets[mask]
    dataset.targets = torch.tensor(
        [DIGIT_TO_CLASS[int(digit)] for digit in raw_targets],
        dtype=torch.long,
    )
    return dataset

train_data = keep_selected_digits(train_data)
test_data = keep_selected_digits(test_data)

BATCH_SIZE = 500

train_loader = DataLoader(
    train_data,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)
test_loader = DataLoader(
    test_data,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)

print("Selected digits:", SELECTED_DIGITS)
print("Train samples:", len(train_data))
print("Test samples:", len(test_data))
# Out:
# Selected digits: (0, 8, 2, 4, 7, 9)
# Train samples: 35788
# Test samples: 6005

# %%
class f(nn.Module):
    def __init__(self, input_dim=784, latent_dim=16, num_classes=6, label_dim=16):
        super().__init__()
        self.latent_dim = latent_dim
        self.num_classes = num_classes
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 192), nn.LeakyReLU(0.2),
            nn.Linear(192, 96), nn.LeakyReLU(0.2),
        )
        self.fc_mu = nn.Linear(96, latent_dim)
        self.fc_var = nn.Linear(96, latent_dim)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 96), nn.LeakyReLU(0.2),
            nn.Linear(96, 192), nn.LeakyReLU(0.2),
            nn.Linear(192, input_dim), nn.Sigmoid(),
        )
        self.embedding = nn.Embedding(num_classes, label_dim)
        self.generator = nn.Sequential(
            nn.Linear(latent_dim + label_dim, 48), nn.SiLU(),
            nn.Linear(48, 48), nn.SiLU(),
            nn.Linear(48, 48), nn.SiLU(),
            nn.Linear(48, latent_dim),
        )

    def reparameterize(self, mu, logvar):
        return mu + torch.randn_like(logvar) * torch.exp(0.5 * logvar)

    def get_latent(self, x):
        h = self.encoder(x)
        mu, logvar = self.fc_mu(h), self.fc_var(h)
        return mu, logvar, self.reparameterize(mu, logvar)

    def encode_mu(self, x):
        return self.fc_mu(self.encoder(x))

    def decode(self, z):
        return self.decoder(z)

    def generate(self, noise, labels):
        h = torch.cat([noise, self.embedding(labels.long())], dim=1)
        z = self.generator(h)
        return z, self.decode(z)

# %%
model = f()
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params}")
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainable parameters: {trainable_params}")
# Out:
# Total parameters: 351088
# Trainable parameters: 351088

# %%
# Keep the drift field fixed while allowing gradients through the re-encoded latent.
def drift_loss(generated, landmarks, K_uu_inv_sqrt, Ap, bp, T):
    with torch.no_grad():
        V = compute_V(generated.detach(), landmarks, K_uu_inv_sqrt, Ap, bp, T)
        frozen_targets = (generated.detach() + V).detach()
    return F.mse_loss(generated, frozen_targets), V

# %%
def build_conditional_drift_cache(model, data_loader, num_classes, num_landmarks, T):
    # Build fixed class-conditional attraction summaries once.
    model.eval()
    references = {digit: [] for digit in range(num_classes)}
    with torch.no_grad():
        for images, labels in data_loader:
            x = images.to(device, non_blocking=True).flatten(start_dim=1)
            _, _, z = model.get_latent(x)
            labels = labels.to(device, non_blocking=True)
            for digit in range(num_classes):
                mask = labels == digit
                if mask.any():
                    references[digit].append(z[mask].detach())

    cache = {}
    bank = []
    for digit in range(num_classes):
        if not references[digit]:
            raise ValueError(f"No reference samples found for digit {digit}.")
        support = torch.cat(references[digit], dim=0)
        bank.append(support)
        landmarks = select_landmarks(support, num_landmarks)
        W = build_nystrom_cache(landmarks, T)
        A, b = pre_compute_summaries(support, landmarks, W, T)
        cache[digit] = (landmarks, W, A, b)
    return cache, torch.cat(bank, dim=0)


def conditional_drift_loss(generated, labels, cache, T):
    total = generated.new_zeros(())
    field = torch.zeros_like(generated)
    batch_size = generated.shape[0]
    for digit_tensor in torch.unique(labels):
        digit = int(digit_tensor.item())
        mask = labels == digit
        landmarks, W, A, b = cache[digit]
        digit_loss, digit_field = drift_loss(
            generated[mask], landmarks, W, A, b, T
        )
        total = total + (mask.float().sum() / batch_size) * digit_loss
        field[mask] = digit_field
    return total, field

def training_loop(num_epochs, T, num_landmarks,
                  lambda_kl, lambda_drift, lambda_var, lambda_cov,
                  lambda_representation=1.0, loss_scale=1.0,
                  batch_size=1000, generator_lr=1e-4, vae_lr=1e-5,
                  cache_resample_interval=10):
    model = f(784, LATENT_DIM, NUM_CLASSES).to(device)
    vae_parameters = (
        list(model.encoder.parameters())
        + list(model.fc_mu.parameters())
        + list(model.fc_var.parameters())
        + list(model.decoder.parameters())
    )
    generator_parameters = (
        list(model.embedding.parameters()) + list(model.generator.parameters())
    )
    # Fully joint: both parameter groups receive gradients from the same loss,
    # but the VAE moves more slowly than the generator.
    optimizer = optim.AdamW([
        {"params": generator_parameters, "lr": generator_lr},
        {"params": vae_parameters, "lr": vae_lr},
    ])
    print(
        f"Joint learning rates: generator={generator_lr:g}, "
        f"VAE/encoder-decoder={vae_lr:g}"
    )
    train_losses, recon_losses, kl_losses = [], [], []
    drift_losses, var_losses, covar_losses = [], [], []
    average_V, evolution = [], []
    space_evolution = []

    print("Building fixed conditional attraction caches...")
    t0 = time.perf_counter()
    cache, _ = build_conditional_drift_cache(
        model, train_loader, NUM_CLASSES, num_landmarks, T
    )
    print(f"Fixed attraction caches built in {(time.perf_counter() - t0) / 60:.2f} minutes")
    print(
        f"Resampling landmarks and attraction summaries every "
        f"{cache_resample_interval} epochs"
    )

    # Fixed probes make latent-space and image snapshots comparable across epochs.
    probe_images, probe_labels = next(iter(test_loader))
    probe_x = probe_images[:500].to(device, non_blocking=True).flatten(start_dim=1)
    probe_labels = probe_labels[:500].to(device, non_blocking=True)
    snapshot_labels = torch.arange(NUM_CLASSES, device=device)
    snapshot_noise = torch.randn(NUM_CLASSES, model.latent_dim, device=device)

    def capture_space_snapshot(epoch, stage):
        model.eval()
        with torch.no_grad():
            real_z = model.encode_mu(probe_x)
            raw_z, generated_images = model.generate(snapshot_noise, snapshot_labels)
            generated_z = model.encode_mu(generated_images)
        space_evolution.append({
            "epoch": epoch,
            "stage": stage,
            "real_latents": real_z.cpu().numpy(),
            "generated_raw_latents": raw_z.cpu().numpy(),
            "generated_reencoded_latents": generated_z.cpu().numpy(),
            "generated_images": generated_images.view(-1, 1, 28, 28).cpu().numpy(),
            "generated_labels": snapshot_labels.cpu().numpy(),
        })

    capture_space_snapshot(-1, "before training")
    print("Fully joint conditional training started")
    snapshots = set(range(0, num_epochs + 1, max(1, num_epochs // 5)))
    snapshots.add(num_epochs)

    for epoch in range(num_epochs + 1):
        if (
            epoch > 0
            and cache_resample_interval > 0
            and epoch % cache_resample_interval == 0
        ):
            cache_start = time.perf_counter()
            print(f"Refreshing DriftXpress cache before epoch {epoch}...")
            cache, _ = build_conditional_drift_cache(
                model, train_loader, NUM_CLASSES, num_landmarks, T
            )
            print(
                f"Cache refreshed in "
                f"{(time.perf_counter() - cache_start) / 60:.2f} minutes"
            )

        model.train()
        items = {k: 0.0 for k in
                 ("total", "recon", "kl", "drift", "var", "covar", "V")}
        last_pos, last_neg = None, None
        for images, labels in train_loader:
            x = images.to(device, non_blocking=True).flatten(start_dim=1)
            labels = labels.to(device, non_blocking=True)
            noise = torch.randn(x.shape[0], model.latent_dim, device=device)
            mu, logvar, z_pos = model.get_latent(x)
            x_recon = model.decode(z_pos)
            z_raw, x_neg = model.generate(noise, labels)
            z_neg = model.encode_mu(x_neg)

            L_drift, V = conditional_drift_loss(z_neg, labels, cache, T)
            L_var = variance_loss(mu) + variance_loss(z_neg)
            L_cov = covariance_loss(mu) + covariance_loss(z_neg)
            L_recon, L_kl = recon_loss(x_recon, x), kl_loss(mu, logvar)
            loss, _ = compose_objective(
                {
                    "recon": L_recon,
                    "kl": L_kl,
                    "drift": L_drift,
                    "var": L_var,
                    "covar": L_cov,
                },
                {
                    "kl": lambda_kl,
                    "drift": lambda_drift,
                    "var": lambda_var,
                    "covar": lambda_cov,
                },
                lambda_representation=lambda_representation,
                loss_scale=loss_scale,
            )
            if not torch.isfinite(loss):
                raise FloatingPointError(f"Non-finite loss at epoch {epoch}: {loss.item()}")
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            optimizer.step()

            items["total"] += loss.item()
            items["recon"] += L_recon.item()
            items["kl"] += L_kl.item()
            items["drift"] += L_drift.item()
            items["var"] += L_var.item()
            items["covar"] += L_cov.item()
            items["V"] += V.norm(dim=1).mean().item()
            last_pos, last_neg = z_pos.detach(), z_neg.detach()

        n = len(train_loader)
        for key in items:
            items[key] /= n
        train_losses.append(items["total"])
        recon_losses.append(items["recon"])
        kl_losses.append(items["kl"])
        drift_losses.append(items["drift"])
        var_losses.append(items["var"])
        covar_losses.append(items["covar"])
        average_V.append(items["V"])
        if epoch in snapshots:
            evolution.append({"epoch": epoch, "pos": last_pos.cpu().numpy(),
                               "neg": last_neg.cpu().numpy()})
            capture_space_snapshot(epoch, "joint training")
        if epoch < 20 or epoch % 10 == 0 or epoch == num_epochs:
            print(f"-------- Epoch {epoch} --------")
            print(f"total={items['total']:.6f}")
            print(f"recon={items['recon']:.6f}    scaled={loss_scale * lambda_representation * items['recon']:.6f}")
            print(f"kl={items['kl']:.6f}    scaled={loss_scale * lambda_representation * lambda_kl * items['kl']:.6f}")
            print(f"drift={items['drift']:.6f}    scaled={loss_scale * lambda_drift * items['drift']:.6f}")
            print(f"var={items['var']:.6f}    scaled={loss_scale * lambda_representation * lambda_var * items['var']:.6f}")
            print("distances", torch.cdist(z_pos[:50], z_pos[:50]).mean().item())
            print(f"covar={items['covar']:.6f}    scaled={loss_scale * lambda_representation * lambda_cov * items['covar']:.6f}")
            print(f"average |V|={items['V']:.6f}")
            print(f"latent std positive={last_pos.std(dim=0).mean().item():.6f}")
            print(f"latent std negative={last_neg.std(dim=0).mean().item():.6f}")

    elapsed = (time.perf_counter() - t0) / 60
    print(f"Finished. Training took {elapsed:.2f} minutes")
    return (model, train_losses, recon_losses, kl_losses,
            drift_losses, var_losses, covar_losses, average_V, evolution, space_evolution)

# %%
# Algorithm 3: fully joint conditional training with image re-encoding for drift.
NUM_CLASSES = 6
LATENT_DIM = 32
NUM_EPOCHS = 100
NUM_LANDMARKS = 200
TEMPERATURE = 1
LAMBDA_KL = 1e-5
LAMBDA_DRIFT = 500.0
LAMBDA_VAR = 0.0
LAMBDA_COV = 0.0
LAMBDA_REPRESENTATION = 20.0
LOSS_SCALE = 1.0
CACHE_RESAMPLE_INTERVAL = 10
GENERATOR_LR = 1e-4
VAE_LR = 1e-5  # Global multiplier; leave at 1 unless intentionally testing it.

f_trained, losses, recon_losses, kl_losses, drift_losses, var_losses, covar_losses, average_V, evolution, space_evolution = training_loop(
    NUM_EPOCHS, TEMPERATURE, NUM_LANDMARKS, LAMBDA_KL, LAMBDA_DRIFT,
    LAMBDA_VAR, LAMBDA_COV,
    lambda_representation=LAMBDA_REPRESENTATION,
    loss_scale=LOSS_SCALE,
    batch_size=BATCH_SIZE,
    generator_lr=GENERATOR_LR,
    vae_lr=VAE_LR,
    cache_resample_interval=CACHE_RESAMPLE_INTERVAL,
)
# Out:
# Joint learning rates: generator=0.0001, VAE/encoder-decoder=1e-05
# Building fixed conditional attraction caches...
# Fixed attraction caches built in 0.12 minutes
# Resampling landmarks and attraction summaries every 10 epochs
# Fully joint conditional training started
# -------- Epoch 0 --------
# total=5.056078
# recon=0.229016    scaled=4.580314
# kl=0.178341    scaled=0.000036
# drift=0.000951    scaled=0.475728
# var=2.964116    scaled=0.000000
# distances 7.59857702255249
# covar=0.000001    scaled=0.000000
# average |V|=0.171239
# latent std positive=1.002675
# latent std negative=0.000045
# -------- Epoch 1 --------
# total=4.912262
# recon=0.226031    scaled=4.520611
# kl=0.179922    scaled=0.000036
# drift=0.000783    scaled=0.391615
# var=2.964095    scaled=0.000000
# distances 7.691525459289551
# covar=0.000001    scaled=0.000000
# average |V|=0.156887
# latent std positive=0.994331
# latent std negative=0.000145
# -------- Epoch 2 --------
# total=4.841945
# recon=0.222651    scaled=4.453024
# kl=0.182711    scaled=0.000037
# drift=0.000778    scaled=0.388884
# var=2.964008    scaled=0.000000
# distances 7.867926597595215
# covar=0.000001    scaled=0.000000
# average |V|=0.156367
# latent std positive=0.995802
# latent std negative=0.000574
# -------- Epoch 3 --------
# total=4.743054
# recon=0.218565    scaled=4.371298
# kl=0.189071    scaled=0.000038
# drift=0.000743    scaled=0.371718
# var=2.963500    scaled=0.000000
# distances 7.729234218597412
# covar=0.000001    scaled=0.000000
# average |V|=0.153092
# latent std positive=0.995860
# latent std negative=0.003460
# -------- Epoch 4 --------
# total=4.569907
# recon=0.213676    scaled=4.273523
# kl=0.201618    scaled=0.000040
# drift=0.000593    scaled=0.296344
# var=2.959537    scaled=0.000000
# distances 7.940143585205078
# covar=0.000002    scaled=0.000000
# average |V|=0.137042
# latent std positive=1.015872
# latent std negative=0.013101
# -------- Epoch 5 --------
# total=4.342015
# recon=0.207983    scaled=4.159660
# kl=0.222120    scaled=0.000044
# drift=0.000365    scaled=0.182310
# var=2.951853    scaled=0.000000
# distances 7.590234756469727
# covar=0.000004    scaled=0.000000
# average |V|=0.106373
# latent std positive=1.016276
# latent std negative=0.019105
# -------- Epoch 6 --------
# total=4.147197
# recon=0.201066    scaled=4.021328
# kl=0.254375    scaled=0.000051
# drift=0.000252    scaled=0.125818
# var=2.947225    scaled=0.000000
# distances 7.692568778991699
# covar=0.000005    scaled=0.000000
# average |V|=0.084636
# latent std positive=1.023572
# latent std negative=0.021375
# -------- Epoch 7 --------
# total=3.959684
# recon=0.192978    scaled=3.859562
# kl=0.316960    scaled=0.000063
# drift=0.000200    scaled=0.100058
# var=2.944092    scaled=0.000000
# distances 8.086799621582031
# covar=0.000007    scaled=0.000000
# average |V|=0.072828
# latent std positive=1.036004
# latent std negative=0.022671
# -------- Epoch 8 --------
# total=3.746471
# recon=0.183283    scaled=3.665661
# kl=0.451097    scaled=0.000090
# drift=0.000161    scaled=0.080719
# var=2.939594    scaled=0.000000
# distances 8.129317283630371
# covar=0.000013    scaled=0.000000
# average |V|=0.064550
# latent std positive=1.066736
# latent std negative=0.023395
# -------- Epoch 9 --------
# total=3.487531
# recon=0.171263    scaled=3.425263
# kl=0.770357    scaled=0.000154
# drift=0.000124    scaled=0.062113
# var=2.931810    scaled=0.000000
# distances 8.681896209716797
# covar=0.000042    scaled=0.000000
# average |V|=0.057170
# latent std positive=1.101047
# latent std negative=0.023927
# Refreshing DriftXpress cache before epoch 10...
# Cache refreshed in 0.12 minutes
# -------- Epoch 10 --------
# total=4.633336
# recon=0.157019    scaled=3.140386
# kl=1.730022    scaled=0.000346
# drift=0.002985    scaled=1.492604
# var=2.918512    scaled=0.000000
# distances 8.948526382446289
# covar=0.000247    scaled=0.000000
# average |V|=0.270351
# latent std positive=1.137667
# latent std negative=0.022281
# -------- Epoch 11 --------
# total=3.142422
# recon=0.143773    scaled=2.875463
# kl=2.468684    scaled=0.000494
# drift=0.000533    scaled=0.266465
# var=2.907810    scaled=0.000000
# distances 9.588495254516602
# covar=0.000475    scaled=0.000000
# average |V|=0.128064
# latent std positive=1.204245
# latent std negative=0.028045
# -------- Epoch 12 --------
# total=2.735761
# recon=0.129680    scaled=2.593605
# kl=3.553613    scaled=0.000711
# drift=0.000283    scaled=0.141446
# var=2.893408    scaled=0.000000
# distances 9.555584907531738
# covar=0.000949    scaled=0.000000
# average |V|=0.093103
# latent std positive=1.235171
# latent std negative=0.031645
# -------- Epoch 13 --------
# total=2.412198
# recon=0.116473    scaled=2.329457
# kl=5.184577    scaled=0.001037
# drift=0.000163    scaled=0.081704
# var=2.877617    scaled=0.000000
# distances 9.956138610839844
# covar=0.001931    scaled=0.000000
# average |V|=0.070784
# latent std positive=1.307185
# latent std negative=0.034782
# -------- Epoch 14 --------
# total=2.151780
# recon=0.105007    scaled=2.100147
# kl=7.520473    scaled=0.001504
# drift=0.000100    scaled=0.050128
# var=2.860754    scaled=0.000000
# distances 10.598337173461914
# covar=0.003921    scaled=0.000000
# average |V|=0.055363
# latent std positive=1.340068
# latent std negative=0.035860
# -------- Epoch 15 --------
# total=1.951289
# recon=0.095959    scaled=1.919174
# kl=10.495405    scaled=0.002099
# drift=0.000060    scaled=0.030015
# var=2.843267    scaled=0.000000
# distances 11.014825820922852
# covar=0.007345    scaled=0.000000
# average |V|=0.042740
# latent std positive=1.432640
# latent std negative=0.037694
# -------- Epoch 16 --------
# total=1.807567
# recon=0.089463    scaled=1.789264
# kl=13.844920    scaled=0.002769
# drift=0.000031    scaled=0.015534
# var=2.826750    scaled=0.000000
# distances 11.810391426086426
# covar=0.012416    scaled=0.000000
# average |V|=0.030700
# latent std positive=1.517345
# latent std negative=0.038098
# -------- Epoch 17 --------
# total=1.708944
# recon=0.084918    scaled=1.698370
# kl=17.203102    scaled=0.003441
# drift=0.000014    scaled=0.007133
# var=2.812024    scaled=0.000000
# distances 11.767759323120117
# covar=0.018917    scaled=0.000000
# average |V|=0.020734
# latent std positive=1.534552
# latent std negative=0.038412
# -------- Epoch 18 --------
# total=1.639199
# recon=0.081596    scaled=1.631915
# kl=20.403602    scaled=0.004081
# drift=0.000006    scaled=0.003203
# var=2.798949    scaled=0.000000
# distances 12.818873405456543
# covar=0.026515    scaled=0.000000
# average |V|=0.013838
# latent std positive=1.622601
# latent std negative=0.039777
# -------- Epoch 19 --------
# total=1.590692
# recon=0.079225    scaled=1.584506
# kl=23.213740    scaled=0.004643
# drift=0.000003    scaled=0.001543
# var=2.787987    scaled=0.000000
# distances 13.830945014953613
# covar=0.034654    scaled=0.000000
# average |V|=0.009559
# latent std positive=1.673593
# latent std negative=0.039249
# Refreshing DriftXpress cache before epoch 20...
# Cache refreshed in 0.12 minutes
# -------- Epoch 20 --------
# total=20.941469
# recon=0.076802    scaled=1.536045
# kl=33.836749    scaled=0.006767
# drift=0.038797    scaled=19.398657
# var=2.735851    scaled=0.000000
# distances 13.507436752319336
# covar=0.071571    scaled=0.000000
# average |V|=1.005621
# latent std positive=1.774348
# latent std negative=0.063011
# Refreshing DriftXpress cache before epoch 30...
# Cache refreshed in 0.12 minutes
# -------- Epoch 30 --------
# total=19.723195
# recon=0.074216    scaled=1.484328
# kl=33.982738    scaled=0.006797
# drift=0.036464    scaled=18.232071
# var=2.611857    scaled=0.000000
# distances 14.022456169128418
# covar=0.094893    scaled=0.000000
# average |V|=1.040198
# latent std positive=1.721586
# latent std negative=0.140501
# Refreshing DriftXpress cache before epoch 40...
# Cache refreshed in 0.11 minutes
# -------- Epoch 40 --------
# total=26.764735
# recon=0.074515    scaled=1.490307
# kl=33.237569    scaled=0.006648
# drift=0.050536    scaled=25.267781
# var=2.557862    scaled=0.000000
# distances 12.931193351745605
# covar=0.133134    scaled=0.000000
# average |V|=1.225166
# latent std positive=1.663987
# latent std negative=0.160465
# Refreshing DriftXpress cache before epoch 50...
# Cache refreshed in 0.12 minutes
# -------- Epoch 50 --------
# total=22.755958
# recon=0.073970    scaled=1.479403
# kl=31.294352    scaled=0.006259
# drift=0.042541    scaled=21.270297
# var=2.540711    scaled=0.000000
# distances 12.463297843933105
# covar=0.153108    scaled=0.000000
# average |V|=1.111053
# latent std positive=1.538327
# latent std negative=0.159445
# Refreshing DriftXpress cache before epoch 60...
# Cache refreshed in 0.12 minutes
# -------- Epoch 60 --------
# total=18.147822
# recon=0.073542    scaled=1.470830
# kl=26.233487    scaled=0.005247
# drift=0.033343    scaled=16.671745
# var=2.568098    scaled=0.000000
# distances 11.48129653930664
# covar=0.133354    scaled=0.000000
# average |V|=0.939924
# latent std positive=1.423322
# latent std negative=0.158739
# Refreshing DriftXpress cache before epoch 70...
# Cache refreshed in 0.10 minutes
# -------- Epoch 70 --------
# total=7.436090
# recon=0.072856    scaled=1.457116
# kl=23.228929    scaled=0.004646
# drift=0.011949    scaled=5.974327
# var=2.616799    scaled=0.000000
# distances 10.569101333618164
# covar=0.119506    scaled=0.000000
# average |V|=0.591486
# latent std positive=1.321380
# latent std negative=0.130123
# Refreshing DriftXpress cache before epoch 80...
# Cache refreshed in 0.11 minutes
# -------- Epoch 80 --------
# total=4.127685
# recon=0.072401    scaled=1.448025
# kl=21.098543    scaled=0.004220
# drift=0.005351    scaled=2.675440
# var=2.633525    scaled=0.000000
# distances 9.239099502563477
# covar=0.117458    scaled=0.000000
# average |V|=0.392761
# latent std positive=1.164642
# latent std negative=0.123327
# Refreshing DriftXpress cache before epoch 90...
# Cache refreshed in 0.10 minutes
# -------- Epoch 90 --------
# total=2.471258
# recon=0.071735    scaled=1.434702
# kl=20.107181    scaled=0.004021
# drift=0.002065    scaled=1.032535
# var=2.657537    scaled=0.000000
# distances 8.355714797973633
# covar=0.118100    scaled=0.000000
# average |V|=0.238100
# latent std positive=1.050528
# latent std negative=0.103898
# Refreshing DriftXpress cache before epoch 100...
# Cache refreshed in 0.12 minutes
# -------- Epoch 100 --------
# total=2.058493
# recon=0.071148    scaled=1.422968
# kl=21.564004    scaled=0.004313
# drift=0.001262    scaled=0.631212
# var=2.659877    scaled=0.000000
# distances 7.353337287902832
# covar=0.139987    scaled=0.000000
# average |V|=0.181073
# latent std positive=0.945230
# latent std negative=0.085020
# Finished. Training took 17.53 minutes

# %%
f_trained.train()
images, labels = next(iter(train_loader))
x = images.to(device).flatten(start_dim=1)
labels = labels.to(device)
noise = torch.randn(x.shape[0], f_trained.latent_dim, device=device)
mu, logvar, z_pos = f_trained.get_latent(x)
z_raw, x_neg = f_trained.generate(noise, labels)
z_neg = f_trained.encode_mu(x_neg)
cache, _ = build_conditional_drift_cache(
    f_trained, train_loader, NUM_CLASSES, NUM_LANDMARKS, TEMPERATURE
)
L_drift, V = conditional_drift_loss(z_neg, labels, cache, TEMPERATURE)
print(gradient_report(L_drift, f_trained))
# Out:
# {'encoder': {'total_norm': 0.21832166262182437, 'nonzero_parameters': 6, 'parameter_count': 8}, 'decoder': {'total_norm': 0.09075238137731448, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 0.008584041689434439, 'nonzero_parameters': 9, 'parameter_count': 9}}

# %%
history = {
    "total": losses, "recon": recon_losses, "kl": kl_losses,
    "drift": drift_losses, "var": var_losses,
    "covar": covar_losses, "force": average_V,
}
fig, axes = plot_loss_history(history)
plt.show()

# %%
def plot_latent_space_evolution(space_evolution, max_real_points=500):
    """Plot real/generated latents using one shared UMAP coordinate system."""
    if not space_evolution:
        raise ValueError("space_evolution is empty; rerun the training cell first.")

    real_parts = [record["real_latents"][:max_real_points] for record in space_evolution]
    generated_parts = [record["generated_reencoded_latents"] for record in space_evolution]
    real_counts = [part.shape[0] for part in real_parts]
    generated_counts = [part.shape[0] for part in generated_parts]
    combined = np.concatenate([*real_parts, *generated_parts], axis=0)

    import umap
    reducer = umap.UMAP(
        n_components=2,
        n_neighbors=15,
        min_dist=0.2,
        metric="euclidean",
        random_state=7,
    )
    embedded = reducer.fit_transform(combined)

    real_offsets = np.cumsum([0, *real_counts])
    generated_offset = sum(real_counts)
    generated_offsets = np.cumsum([generated_offset, *generated_counts])

    figure, axes = plt.subplots(
        len(space_evolution),
        1,
        figsize=(8, 3.2 * len(space_evolution)),
        squeeze=False,
    )
    axes = axes[:, 0]
    x_min, x_max = embedded[:, 0].min(), embedded[:, 0].max()
    y_min, y_max = embedded[:, 1].min(), embedded[:, 1].max()
    x_pad = max(1e-6, 0.05 * (x_max - x_min))
    y_pad = max(1e-6, 0.05 * (y_max - y_min))

    for index, record in enumerate(space_evolution):
        real_start, real_end = real_offsets[index], real_offsets[index + 1]
        gen_start, gen_end = generated_offsets[index], generated_offsets[index + 1]
        axis = axes[index]
        axis.scatter(
            embedded[real_start:real_end, 0],
            embedded[real_start:real_end, 1],
            s=8,
            alpha=0.25,
            label="real encoded latents",
        )
        axis.scatter(
            embedded[gen_start:gen_end, 0],
            embedded[gen_start:gen_end, 1],
            s=45,
            marker="x",
            linewidths=1.5,
            label="generated re-encoded latents",
        )
        axis.set_title(f"UMAP — {record['stage']}")
        axis.set_xlim(x_min - x_pad, x_max + x_pad)
        axis.set_ylim(y_min - y_pad, y_max + y_pad)
        axis.grid(alpha=0.2)
        axis.legend()

    figure.suptitle("Latent-space evolution during fully joint training", y=1.0)
    figure.tight_layout()
    return figure, axes


def plot_generated_sample_evolution(space_evolution):
    """Show the same generated labels/noise at every checkpoint."""
    if not space_evolution:
        raise ValueError("space_evolution is empty; rerun the training cell first.")

    n_rows = len(space_evolution)
    n_columns = space_evolution[0]["generated_images"].shape[0]
    figure, axes = plt.subplots(
        n_rows,
        n_columns,
        figsize=(1.8 * n_columns, 1.65 * n_rows),
        squeeze=False,
    )
    digits = CLASS_TO_DIGIT[space_evolution[0]["generated_labels"]]

    for row, record in enumerate(space_evolution):
        for column in range(n_columns):
            axis = axes[row, column]
            axis.imshow(record["generated_images"][column, 0], cmap="gray", vmin=0, vmax=1)
            axis.axis("off")
            if row == 0:
                axis.set_title(str(int(digits[column])))
        axes[row, 0].set_ylabel(
            record["stage"],
            rotation=0,
            ha="right",
            va="center",
            fontsize=8,
            labelpad=12,
        )

    figure.suptitle("Generated samples at training checkpoints")
    figure.tight_layout()
    return figure, axes


fig_space_umap, axes_space_umap = plot_latent_space_evolution(space_evolution)
plt.show()

fig_generation_evolution, axes_generation_evolution = plot_generated_sample_evolution(space_evolution)
plt.show()
# Out:
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# One reusable post-training call: it collects real encoder means and
# conditional generated latents/images, then computes latent SWD/FID and class metrics.
post_eval = evaluate_latent_model(
    f_trained,
    test_loader,
    device=device,
    n_samples=2048,
    n_classes=NUM_CLASSES,
    class_to_label=CLASS_TO_DIGIT,
    include_mmd=False,
    include_fid=True,
)

samples = post_eval["samples"]
real_latents = samples["real_latents"]
generated_latents = samples["generated_latents"]
real_pixels = samples["real_images"]
generated_pixels = samples["generated_images"]
real_class_labels = samples["real_class_ids"]
generated_class_labels = samples["generated_class_ids"]
real_labels = samples["real_labels"]
generated_labels = samples["generated_labels"]
metrics = post_eval["metrics"]
latent_stats = post_eval["statistics"]

print("Latent-space metrics:")
for name, value in metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent-space metrics:
# sliced_wasserstein: 65.829742
# fid: 241954.606518
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
# This is the same compact metric interface in pixel space.
# Its FID is a pixel-space Fréchet distance; use evaluate_mnist_generation with a
# frozen evaluator when you specifically want learned MNIST-feature FID.
pixel_metrics = evaluate_generation(
    real_pixels,
    generated_pixels,
    generated_labels=generated_class_labels,
    n_classes=NUM_CLASSES,
    include_mmd=False,
)
print("Pixel-space metrics:")
for name, value in pixel_metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Pixel-space metrics:
# sliced_wasserstein: 0.305982
# fid: 219.510441
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
print("Latent statistics:")
for name, value in latent_stats.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent statistics:
# real_latent_mean: 0.153943
# generated_latent_mean: -20.447853
# real_latent_std: 0.230467
# generated_latent_std: 67.011431
# generated_to_real_std_ratio: 290.763909
# real_total_correlation: 53.934524
# generated_total_correlation: 185.882828

# %%
fig, axes = plot_conditional_mnist_results(
    f_trained,
    test_loader,
    device=device,
    samples=10,
    use_mean_for_reconstruction=True,
)
plt.show()

# %%
projection_figures = plot_real_generated_projections(
    real_latents,
    generated_latents,
    real_labels=real_labels,
    generated_labels=generated_labels,
    methods=("umap",),
)
plt.show()
# Out:
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\mateo\anaconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:328: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\mateo\anaconda3\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:328: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
