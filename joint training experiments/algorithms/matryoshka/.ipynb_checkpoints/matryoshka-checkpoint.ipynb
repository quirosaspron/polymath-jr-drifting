# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms, utils
from torch.utils.data import DataLoader
# %cd "C:/Users/mateo/Desktop/polymath-jr-drifting"
# The reusable nested-prefix implementation lives in src.matryoshka.
import importlib
import src.matryoshka as matryoshka_utils
matryoshka_utils = importlib.reload(matryoshka_utils)
from src.driftXpress import *
from src.eval import *
from src.training import (
    compose_objective,
    format_epoch_losses,
    gradient_report,
    per_loss_gradient_norms,
    set_requires_grad,
)
from src.matryoshka import (
    VAE,
    LatentGenerator,
    f,
    build_conditional_drift_cache,
    conditional_drift_loss,
    evaluate_matryoshka_model,
    training_loop as matryoshka_training_loop,
)
torch.manual_seed(7)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# C:\Users\mateo\Desktop\polymath-jr-drifting
# Using: cuda

# %%
transform = transforms.ToTensor()

SELECTED_DIGITS = (0, 8, 2, 4, 7, 9)
DIGIT_TO_CLASS = {digit: index for index, digit in enumerate(SELECTED_DIGITS)}
CLASS_TO_DIGIT = np.asarray(SELECTED_DIGITS)

train_data = datasets.MNIST("data", train=True, download=True, transform=transform)
test_data = datasets.MNIST("data", train=False, download=True, transform=transform)

def keep_selected_digits(dataset):
    selected = torch.tensor(SELECTED_DIGITS, dtype=dataset.targets.dtype)
    mask = torch.isin(dataset.targets, selected)
    dataset.data = dataset.data[mask]
    raw_targets = dataset.targets[mask]
    dataset.targets = torch.tensor(
        [DIGIT_TO_CLASS[int(digit)] for digit in raw_targets],
        dtype=torch.long,
    )
    return dataset

train_data = keep_selected_digits(train_data)
test_data = keep_selected_digits(test_data)

BATCH_SIZE = 500

train_loader = DataLoader(
    train_data,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)
test_loader = DataLoader(
    test_data,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)

print("Selected digits:", SELECTED_DIGITS)
print("Train samples:", len(train_data))
print("Test samples:", len(test_data))
# Out:
# Selected digits: (0, 8, 2, 4, 7, 9)
# Train samples: 35788
# Test samples: 6005

# %%
# VAE, generator, and wrapper classes are defined in src/matryoshka.py.
# Their public names remain VAE, LatentGenerator, and f to match separate.ipynb.

# %%
vae = VAE()
gen = LatentGenerator()
model = f(vae, gen)
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params}")
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainable parameters: {trainable_params}")
# Out:
# Total parameters: 351088
# Trainable parameters: 351088

# %%
model = VAE()
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params}")
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainable parameters: {trainable_params}")
# Out:
# Total parameters: 343920
# Trainable parameters: 343920

# %%
model = LatentGenerator()
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params}")
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainable parameters: {trainable_params}")
# Out:
# Total parameters: 7168
# Trainable parameters: 7168

# %%
def training_loop(num_epochs, T, num_landmarks,
                  lambda_kl, lambda_drift, lambda_var, lambda_cov,
                  batch_size=1000, lr=1e-3):
    # Keep the original notebook call signature and history tuple.
    return matryoshka_training_loop(
        num_epochs, T, num_landmarks, lambda_kl, lambda_drift,
        lambda_var, lambda_cov, batch_size=batch_size, lr=lr,
        train_loader=train_loader, device=device, num_classes=NUM_CLASSES,
        latent_dim=LATENT_DIM, matryoshka_dims=MATRYOSHKA_DIMS,
    )

# %%
# Algorithm 2 with Matryoshka representation learning at nested latent prefixes.
NUM_CLASSES = 6
LATENT_DIM = 32
MATRYOSHKA_DIMS = (4, 8, 16, 32)
NUM_EPOCHS = 100
NUM_LANDMARKS = 200
TEMPERATURE = 2
LAMBDA_KL = 1e-5
LAMBDA_DRIFT = 30.0
LAMBDA_VAR = 0.0
LAMBDA_COV = 0.0

f_trained, losses, recon_losses, kl_losses, drift_losses, var_losses, covar_losses, average_V, evolution = training_loop(
    NUM_EPOCHS, TEMPERATURE, NUM_LANDMARKS, LAMBDA_KL, LAMBDA_DRIFT,
    LAMBDA_VAR, LAMBDA_COV, batch_size=BATCH_SIZE, lr=1e-3,
)
# Out:
# VAE training started
# -------- VAE epoch 0 --------
# total=0.098494
# recon=0.097771
# kl=72.307689
# var=0.897689
# distances 6.759775638580322
# covar=8.741931
# -------- VAE epoch 1 --------
# total=0.063881
# recon=0.063480
# kl=40.080855
# var=0.498706
# distances 8.355048179626465
# covar=45.389351
# -------- VAE epoch 2 --------
# total=0.054987
# recon=0.054565
# kl=42.266549
# var=0.346013
# distances 11.080034255981445
# covar=56.662611
# -------- VAE epoch 3 --------
# total=0.045640
# recon=0.045063
# kl=57.682700
# var=0.264019
# distances 12.930859565734863
# covar=48.602910
# -------- VAE epoch 4 --------
# total=0.039389
# recon=0.038728
# kl=66.077788
# var=0.268847
# distances 12.946392059326172
# covar=29.942295
# -------- VAE epoch 5 --------
# total=0.035833
# recon=0.035135
# kl=69.805703
# var=0.241775
# distances 13.823674201965332
# covar=23.070887
# -------- VAE epoch 6 --------
# total=0.033141
# recon=0.032425
# kl=71.564223
# var=0.213972
# distances 13.772069931030273
# covar=20.551288
# -------- VAE epoch 7 --------
# total=0.031168
# recon=0.030454
# kl=71.361631
# var=0.190271
# distances 14.71340274810791
# covar=15.554065
# -------- VAE epoch 8 --------
# total=0.029597
# recon=0.028888
# kl=70.913349
# var=0.182405
# distances 13.543707847595215
# covar=12.321879
# -------- VAE epoch 9 --------
# total=0.028388
# recon=0.027685
# kl=70.289647
# var=0.172166
# distances 13.558819770812988
# covar=10.504435
# -------- VAE epoch 10 --------
# total=0.027406
# recon=0.026709
# kl=69.715797
# var=0.162635
# distances 14.052796363830566
# covar=9.847413
# -------- VAE epoch 11 --------
# total=0.026619
# recon=0.025928
# kl=69.067406
# var=0.158090
# distances 13.923068046569824
# covar=9.203948
# -------- VAE epoch 12 --------
# total=0.025942
# recon=0.025256
# kl=68.581378
# var=0.155151
# distances 13.174437522888184
# covar=8.617134
# -------- VAE epoch 13 --------
# total=0.025400
# recon=0.024720
# kl=67.954339
# var=0.152980
# distances 13.286229133605957
# covar=7.746446
# -------- VAE epoch 14 --------
# total=0.024904
# recon=0.024232
# kl=67.202693
# var=0.151322
# distances 12.511043548583984
# covar=6.824753
# -------- VAE epoch 15 --------
# total=0.024480
# recon=0.023812
# kl=66.808434
# var=0.149627
# distances 12.801308631896973
# covar=6.141433
# -------- VAE epoch 16 --------
# total=0.024090
# recon=0.023429
# kl=66.118778
# var=0.149008
# distances 12.562872886657715
# covar=5.575047
# -------- VAE epoch 17 --------
# total=0.023765
# recon=0.023110
# kl=65.494420
# var=0.148654
# distances 12.699542999267578
# covar=5.118761
# -------- VAE epoch 18 --------
# total=0.023462
# recon=0.022811
# kl=65.022549
# var=0.149167
# distances 12.290677070617676
# covar=4.573586
# -------- VAE epoch 19 --------
# total=0.023153
# recon=0.022508
# kl=64.565741
# var=0.148930
# distances 11.613773345947266
# covar=4.270030
# -------- VAE epoch 20 --------
# total=0.022909
# recon=0.022269
# kl=63.965832
# var=0.149085
# distances 11.743453979492188
# covar=3.851002
# -------- VAE epoch 30 --------
# total=0.021194
# recon=0.020591
# kl=60.372009
# var=0.156124
# distances 11.391654014587402
# covar=2.576592
# -------- VAE epoch 40 --------
# total=0.020219
# recon=0.019635
# kl=58.409429
# var=0.165286
# distances 10.7836275100708
# covar=2.000475
# -------- VAE epoch 50 --------
# total=0.019584
# recon=0.019015
# kl=56.907652
# var=0.176146
# distances 10.413179397583008
# covar=1.668587
# -------- VAE epoch 60 --------
# total=0.019114
# recon=0.018554
# kl=56.019981
# var=0.188104
# distances 10.136434555053711
# covar=1.476003
# -------- VAE epoch 70 --------
# total=0.018747
# recon=0.018195
# kl=55.239473
# var=0.200570
# distances 10.135714530944824
# covar=1.304939
# -------- VAE epoch 80 --------
# total=0.018415
# recon=0.017869
# kl=54.672974
# var=0.213514
# distances 9.887099266052246
# covar=1.213836
# -------- VAE epoch 90 --------
# total=0.018157
# recon=0.017615
# kl=54.152564
# var=0.223941
# distances 9.843636512756348
# covar=1.144082
# -------- VAE epoch 100 --------
# total=0.017944
# recon=0.017406
# kl=53.796893
# var=0.234112
# distances 9.38637924194336
# covar=1.064143
# Building fixed conditional attraction caches...
# Fixed attraction caches built in 0.13 minutes
# Conditional generator training started
# -------- Generator epoch 0 --------
# total=26.404113
# drift=0.880137    scaled=26.404113
# var=1.189823    scaled=0.000000
# distances 9.537111282348633
# covar=0.667065    scaled=0.000000
# average |V|=2.678462
# latent std positive=1.083783
# latent std negative=0.460345
# -------- Generator epoch 1 --------
# total=1.026410
# drift=0.034214    scaled=1.026410
# var=0.661141    scaled=0.000000
# distances 9.537111282348633
# covar=3.063899    scaled=0.000000
# average |V|=0.480877
# latent std positive=1.083783
# latent std negative=0.484367
# -------- Generator epoch 2 --------
# total=0.374512
# drift=0.012484    scaled=0.374512
# var=0.612858    scaled=0.000000
# distances 9.537111282348633
# covar=2.780626    scaled=0.000000
# average |V|=0.287568
# latent std positive=1.083783
# latent std negative=0.551043
# -------- Generator epoch 3 --------
# total=0.496466
# drift=0.016549    scaled=0.496466
# var=0.600875    scaled=0.000000
# distances 9.537111282348633
# covar=1.591735    scaled=0.000000
# average |V|=0.340027
# latent std positive=1.083783
# latent std negative=0.554391
# -------- Generator epoch 4 --------
# total=0.507815
# drift=0.016927    scaled=0.507815
# var=0.596755    scaled=0.000000
# distances 9.537111282348633
# covar=1.362237    scaled=0.000000
# average |V|=0.343102
# latent std positive=1.083783
# latent std negative=0.553450
# -------- Generator epoch 5 --------
# total=0.487942
# drift=0.016265    scaled=0.487942
# var=0.593351    scaled=0.000000
# distances 9.537111282348633
# covar=1.303066    scaled=0.000000
# average |V|=0.339156
# latent std positive=1.083783
# latent std negative=0.569872
# -------- Generator epoch 6 --------
# total=0.483244
# drift=0.016108    scaled=0.483244
# var=0.588690    scaled=0.000000
# distances 9.537111282348633
# covar=1.266604    scaled=0.000000
# average |V|=0.336708
# latent std positive=1.083783
# latent std negative=0.566200
# -------- Generator epoch 7 --------
# total=0.477278
# drift=0.015909    scaled=0.477278
# var=0.584997    scaled=0.000000
# distances 9.537111282348633
# covar=1.276333    scaled=0.000000
# average |V|=0.335580
# latent std positive=1.083783
# latent std negative=0.569879
# -------- Generator epoch 8 --------
# total=0.473126
# drift=0.015771    scaled=0.473126
# var=0.581427    scaled=0.000000
# distances 9.537111282348633
# covar=1.254452    scaled=0.000000
# average |V|=0.331439
# latent std positive=1.083783
# latent std negative=0.581996
# -------- Generator epoch 9 --------
# total=0.455616
# drift=0.015187    scaled=0.455616
# var=0.578243    scaled=0.000000
# distances 9.537111282348633
# covar=1.270185    scaled=0.000000
# average |V|=0.327067
# latent std positive=1.083783
# latent std negative=0.581815
# -------- Generator epoch 10 --------
# total=0.474608
# drift=0.015820    scaled=0.474608
# var=0.574381    scaled=0.000000
# distances 9.537111282348633
# covar=1.279372    scaled=0.000000
# average |V|=0.335950
# latent std positive=1.083783
# latent std negative=0.561085
# -------- Generator epoch 11 --------
# total=0.474096
# drift=0.015803    scaled=0.474096
# var=0.571029    scaled=0.000000
# distances 9.537111282348633
# covar=1.244838    scaled=0.000000
# average |V|=0.332692
# latent std positive=1.083783
# latent std negative=0.580656
# -------- Generator epoch 12 --------
# total=0.490282
# drift=0.016343    scaled=0.490282
# var=0.566102    scaled=0.000000
# distances 9.537111282348633
# covar=1.257110    scaled=0.000000
# average |V|=0.342341
# latent std positive=1.083783
# latent std negative=0.592919
# -------- Generator epoch 13 --------
# total=0.467110
# drift=0.015570    scaled=0.467110
# var=0.560773    scaled=0.000000
# distances 9.537111282348633
# covar=1.249674    scaled=0.000000
# average |V|=0.333717
# latent std positive=1.083783
# latent std negative=0.590699
# -------- Generator epoch 14 --------
# total=0.461133
# drift=0.015371    scaled=0.461133
# var=0.556063    scaled=0.000000
# distances 9.537111282348633
# covar=1.267742    scaled=0.000000
# average |V|=0.331436
# latent std positive=1.083783
# latent std negative=0.600184
# -------- Generator epoch 15 --------
# total=0.483953
# drift=0.016132    scaled=0.483953
# var=0.548705    scaled=0.000000
# distances 9.537111282348633
# covar=1.226282    scaled=0.000000
# average |V|=0.341493
# latent std positive=1.083783
# latent std negative=0.620981
# -------- Generator epoch 16 --------
# total=0.465706
# drift=0.015524    scaled=0.465706
# var=0.545705    scaled=0.000000
# distances 9.537111282348633
# covar=1.231882    scaled=0.000000
# average |V|=0.333897
# latent std positive=1.083783
# latent std negative=0.599311
# -------- Generator epoch 17 --------
# total=0.476472
# drift=0.015882    scaled=0.476472
# var=0.539705    scaled=0.000000
# distances 9.537111282348633
# covar=1.242277    scaled=0.000000
# average |V|=0.339477
# latent std positive=1.083783
# latent std negative=0.597258
# -------- Generator epoch 18 --------
# total=0.470971
# drift=0.015699    scaled=0.470971
# var=0.536137    scaled=0.000000
# distances 9.537111282348633
# covar=1.222730    scaled=0.000000
# average |V|=0.338206
# latent std positive=1.083783
# latent std negative=0.611734
# -------- Generator epoch 19 --------
# total=0.501468
# drift=0.016716    scaled=0.501468
# var=0.532372    scaled=0.000000
# distances 9.537111282348633
# covar=1.277264    scaled=0.000000
# average |V|=0.348329
# latent std positive=1.083783
# latent std negative=0.612310
# -------- Generator epoch 20 --------
# total=0.478125
# drift=0.015937    scaled=0.478125
# var=0.530160    scaled=0.000000
# distances 9.537111282348633
# covar=1.241792    scaled=0.000000
# average |V|=0.340977
# latent std positive=1.083783
# latent std negative=0.627021
# -------- Generator epoch 30 --------
# total=0.490820
# drift=0.016361    scaled=0.490820
# var=0.500299    scaled=0.000000
# distances 9.537111282348633
# covar=1.270951    scaled=0.000000
# average |V|=0.347794
# latent std positive=1.083783
# latent std negative=0.630074
# -------- Generator epoch 40 --------
# total=0.520594
# drift=0.017353    scaled=0.520594
# var=0.474861    scaled=0.000000
# distances 9.537111282348633
# covar=1.233273    scaled=0.000000
# average |V|=0.363249
# latent std positive=1.083783
# latent std negative=0.661586
# -------- Generator epoch 50 --------
# total=0.538672
# drift=0.017956    scaled=0.538672
# var=0.459514    scaled=0.000000
# distances 9.537111282348633
# covar=1.222420    scaled=0.000000
# average |V|=0.369880
# latent std positive=1.083783
# latent std negative=0.662610
# -------- Generator epoch 60 --------
# total=0.523580
# drift=0.017453    scaled=0.523580
# var=0.451592    scaled=0.000000
# distances 9.537111282348633
# covar=1.207470    scaled=0.000000
# average |V|=0.364506
# latent std positive=1.083783
# latent std negative=0.709080
# -------- Generator epoch 70 --------
# total=0.529708
# drift=0.017657    scaled=0.529708
# var=0.447109    scaled=0.000000
# distances 9.537111282348633
# covar=1.204471    scaled=0.000000
# average |V|=0.367724
# latent std positive=1.083783
# latent std negative=0.685103
# -------- Generator epoch 80 --------
# total=0.538560
# drift=0.017952    scaled=0.538560
# var=0.444386    scaled=0.000000
# distances 9.537111282348633
# covar=1.186708    scaled=0.000000
# average |V|=0.373720
# latent std positive=1.083783
# latent std negative=0.699089
# -------- Generator epoch 90 --------
# total=0.552537
# drift=0.018418    scaled=0.552537
# var=0.441159    scaled=0.000000
# distances 9.537111282348633
# covar=1.160652    scaled=0.000000
# average |V|=0.375381
# latent std positive=1.083783
# latent std negative=0.695719
# -------- Generator epoch 100 --------
# total=0.539610
# drift=0.017987    scaled=0.539610
# var=0.437331    scaled=0.000000
# distances 9.537111282348633
# covar=1.169351    scaled=0.000000
# average |V|=0.373331
# latent std positive=1.083783
# latent std negative=0.694237
# Separate training finished

# %%
f_trained.train()
images, labels = next(iter(train_loader))
x = images.to(device).flatten(start_dim=1)
labels = labels.to(device)
noise = torch.randn(x.shape[0], f_trained.latent_dim, device=device)
z_neg, _ = f_trained.generate(noise, labels)
cache, _ = build_conditional_drift_cache(
    f_trained, train_loader, NUM_CLASSES, NUM_LANDMARKS, TEMPERATURE,
    matryoshka_dims=MATRYOSHKA_DIMS,
)
L_drift, V = conditional_drift_loss(
    z_neg, labels, cache, TEMPERATURE, matryoshka_dims=MATRYOSHKA_DIMS,
)
print(gradient_report(L_drift, f_trained.generator_model))
# Out:
# {'encoder': {'total_norm': 0.0, 'nonzero_parameters': 0, 'parameter_count': 0}, 'decoder': {'total_norm': 0.0, 'nonzero_parameters': 0, 'parameter_count': 0}, 'generator': {'total_norm': 0.22588362696855951, 'nonzero_parameters': 9, 'parameter_count': 9}}

# %%
history = {
    "total": losses, "recon": recon_losses, "kl": kl_losses,
    "drift": drift_losses, "var": var_losses,
    "covar": covar_losses, "force": average_V,
}
fig, axes = plot_loss_history(history)
plt.show()

# %%
# Full-space metrics remain available under the same variables as separate.ipynb.
# Additional metrics are computed independently for every nested prefix.
post_eval = evaluate_matryoshka_model(
    f_trained,
    test_loader,
    device=device,
    dimensions=MATRYOSHKA_DIMS,
    n_samples=2048,
    n_classes=NUM_CLASSES,
    class_to_label=CLASS_TO_DIGIT,
    include_mmd=False,
    include_fid=True,
)

samples = post_eval["samples"]
real_latents = samples["real_latents"]
generated_latents = samples["generated_latents"]
real_pixels = samples["real_images"]
generated_pixels = samples["generated_images"]
real_class_labels = samples["real_class_ids"]
generated_class_labels = samples["generated_class_ids"]
real_labels = samples["real_labels"]
generated_labels = samples["generated_labels"]
metrics = post_eval["metrics"]
latent_stats = post_eval["statistics"]

print("Latent-space metrics:")
for name, value in metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent-space metrics:
# sliced_wasserstein: 0.241662
# fid: 8.204008
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
# This is the same compact metric interface in pixel space.
# Its FID is a pixel-space Fréchet distance; use evaluate_mnist_generation with a
# frozen evaluator when you specifically want learned MNIST-feature FID.
pixel_metrics = evaluate_generation(
    real_pixels,
    generated_pixels,
    generated_labels=generated_class_labels,
    n_classes=NUM_CLASSES,
    include_mmd=False,
)
print("Pixel-space metrics:")
for name, value in pixel_metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Pixel-space metrics:
# sliced_wasserstein: 0.038828
# fid: 7.164247
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
print("Latent statistics:")
for name, value in latent_stats.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent statistics:
# real_latent_mean: 0.027601
# generated_latent_mean: 0.053181
# real_latent_std: 1.039626
# generated_latent_std: 0.690680
# generated_to_real_std_ratio: 0.664354
# real_total_correlation: 3.298621
# generated_total_correlation: 14.500163

# %%
matryoshka_metrics = post_eval["matryoshka_metrics"]
matryoshka_statistics = post_eval["matryoshka_statistics"]
prefix_reconstruction_mse = post_eval["matryoshka_reconstruction_mse"]
print("Matryoshka prefix metrics:")
for dimension in MATRYOSHKA_DIMS:
    print(f"dimension={dimension}")
    for name, value in matryoshka_metrics[dimension].items():
        print(f"{name}: {value:.6f}")
    print(f"reconstruction_mse: {prefix_reconstruction_mse[dimension]:.6f}")
# Out:
# Matryoshka prefix metrics:
# dimension=4
# sliced_wasserstein: 0.411481
# fid: 0.907020
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.031524
# dimension=8
# sliced_wasserstein: 0.306807
# fid: 1.285577
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.019290
# dimension=16
# sliced_wasserstein: 0.264070
# fid: 3.935462
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.012336
# dimension=32
# sliced_wasserstein: 0.241662
# fid: 8.204008
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.009690

# %%
fig, axes = plot_conditional_mnist_results(
    f_trained,
    test_loader,
    device=device,
    samples=10,
    use_mean_for_reconstruction=True,
)
plt.show()

# %%
projection_figures = plot_real_generated_projections(
    real_latents,
    generated_latents,
    real_labels=real_labels,
    generated_labels=generated_labels,
    methods=("pca", "umap"),
)
plt.show()
# Out:
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
import importlib
import src.matryoshka as matryoshka_utils
matryoshka_utils = importlib.reload(matryoshka_utils)
plot_matryoshka_diagnostics = matryoshka_utils.plot_matryoshka_diagnostics
plot_matryoshka_reconstructions = matryoshka_utils.plot_matryoshka_reconstructions

fig, axes = plot_matryoshka_diagnostics(
    matryoshka_metrics,
    prefix_reconstruction_mse,
)
plt.show()

fig, axes = plot_matryoshka_reconstructions(
    f_trained,
    test_loader,
    MATRYOSHKA_DIMS,
    device=device,
    samples=10,
)
plt.show()
