# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms, utils
from torch.utils.data import DataLoader
# %cd "C:/Users/mateo/Desktop/polymath-jr-drifting"
import importlib
import src.matryoshka as matryoshka_utils
matryoshka_utils = importlib.reload(matryoshka_utils)
from src.driftXpress import *
from src.eval import (
    evaluate_generation,
    plot_conditional_mnist_results,
    plot_loss_history,
    plot_real_generated_projections,
)
from src.training import (
    compose_objective,
    format_epoch_losses,
    gradient_report,
    per_loss_gradient_norms,
    set_requires_grad,
)
from src.matryoshka import (
    VAE,
    LatentGenerator,
    f,
    conditional_drift_loss,
    evaluate_matryoshka_model,
    plot_matryoshka_diagnostics,
    plot_matryoshka_reconstructions,
    pretrained_full_joint_training_loop,
)
torch.manual_seed(7)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# C:\Users\mateo\Desktop\polymath-jr-drifting
# Using: cuda

# %%
transform = transforms.ToTensor()

SELECTED_DIGITS = (0, 8, 2, 4, 7, 9)
DIGIT_TO_CLASS = {digit: index for index, digit in enumerate(SELECTED_DIGITS)}
CLASS_TO_DIGIT = np.asarray(SELECTED_DIGITS)

train_data = datasets.MNIST("data", train=True, download=True, transform=transform)
test_data = datasets.MNIST("data", train=False, download=True, transform=transform)

def keep_selected_digits(dataset):
    selected = torch.tensor(SELECTED_DIGITS, dtype=dataset.targets.dtype)
    mask = torch.isin(dataset.targets, selected)
    dataset.data = dataset.data[mask]
    raw_targets = dataset.targets[mask]
    dataset.targets = torch.tensor(
        [DIGIT_TO_CLASS[int(digit)] for digit in raw_targets],
        dtype=torch.long,
    )
    return dataset

train_data = keep_selected_digits(train_data)
test_data = keep_selected_digits(test_data)

BATCH_SIZE = 500

train_loader = DataLoader(
    train_data,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)
test_loader = DataLoader(
    test_data,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)

print("Selected digits:", SELECTED_DIGITS)
print("Train samples:", len(train_data))
print("Test samples:", len(test_data))
# Out:
# Selected digits: (0, 8, 2, 4, 7, 9)
# Train samples: 35788
# Test samples: 6005

# %%
NUM_CLASSES = 6
LATENT_DIM = 32
MATRYOSHKA_DIMS = (4, 8, 16, 32)
model = f(
    VAE(input_dim=784, latent_dim=LATENT_DIM, matryoshka_dims=MATRYOSHKA_DIMS),
    LatentGenerator(latent_dim=LATENT_DIM, num_classes=NUM_CLASSES, matryoshka_dims=MATRYOSHKA_DIMS),
    num_classes=NUM_CLASSES,
)
print(f"Total parameters: {sum(parameter.numel() for parameter in model.parameters())}")
print(f"Trainable parameters: {sum(parameter.numel() for parameter in model.parameters() if parameter.requires_grad)}")
# Out:
# Total parameters: 357280
# Trainable parameters: 357280

# %%
def training_loop(
    num_epochs,
    T,
    num_landmarks,
    lambda_kl,
    lambda_drift,
    lambda_var,
    lambda_cov,
    lambda_representation=1.0,
    loss_scale=1.0,
    vae_pretrain_epochs=50,
    generator_warmup_epochs=30,
    generator_drift_warmup_epochs=25,
    generator_lr=1e-3,
    generator_drift_lr=1e-4,
    joint_generator_lr=1e-4,
    joint_vae_lr=1e-5,
    raw_drift_weight=0.25,
    lr=1e-4,
):
    # Keep pretrained-full-joint.ipynb's call signature and return tuple.
    return pretrained_full_joint_training_loop(
        num_epochs, T, num_landmarks, lambda_kl, lambda_drift,
        lambda_var, lambda_cov,
        lambda_representation=lambda_representation,
        loss_scale=loss_scale,
        vae_pretrain_epochs=vae_pretrain_epochs,
        generator_warmup_epochs=generator_warmup_epochs,
        generator_drift_warmup_epochs=generator_drift_warmup_epochs,
        generator_lr=generator_lr,
        generator_drift_lr=generator_drift_lr,
        joint_generator_lr=joint_generator_lr,
        joint_vae_lr=joint_vae_lr,
        raw_drift_weight=raw_drift_weight,
        lr=lr,
        train_loader=train_loader,
        device=device,
        num_classes=NUM_CLASSES,
        latent_dim=LATENT_DIM,
        matryoshka_dims=MATRYOSHKA_DIMS,
    )

# %%
# Pretraining and all warmups use nested prefix losses before the fully joint phase.
VAE_PRETRAIN_EPOCHS = 50
GENERATOR_WARMUP_EPOCHS = 30
NUM_EPOCHS = 100
NUM_LANDMARKS = 200
TEMPERATURE = 2
LAMBDA_KL = 1e-5
LAMBDA_DRIFT = 30.0
LAMBDA_VAR = 0.0
LAMBDA_COV = 0.0
LAMBDA_REPRESENTATION = 20.0
LOSS_SCALE = 1.0  # Keep at 1.0; it is an intentional global gradient-scale test.

(
    f_trained,
    losses,
    recon_losses,
    kl_losses,
    drift_losses,
    var_losses,
    covar_losses,
    average_V,
    evolution,
    pretrain_history,
    generator_warmup_history,
    generator_drift_history,
    drift_raw_losses,
) = training_loop(
    NUM_EPOCHS,
    TEMPERATURE,
    NUM_LANDMARKS,
    LAMBDA_KL,
    LAMBDA_DRIFT,
    LAMBDA_VAR,
    LAMBDA_COV,
    lambda_representation=LAMBDA_REPRESENTATION,
    loss_scale=LOSS_SCALE,
    vae_pretrain_epochs=VAE_PRETRAIN_EPOCHS,
    generator_warmup_epochs=GENERATOR_WARMUP_EPOCHS,
    generator_drift_warmup_epochs=25,
    generator_lr=1e-3,
    generator_drift_lr=1e-4,
    joint_generator_lr=1e-4,
    joint_vae_lr=1e-5,
    raw_drift_weight=0.25,
    lr=1e-4,
)
# Out:
# Pretraining the VAE part for 50 epochs (generator frozen)...
# -------- VAE pretrain epoch 1/50 --------
# total=0.206302
# representation=0.206302    scaled=0.206302
# recon=0.206260    scaled=0.206260
# kl=4.194881    scaled=0.000042
# var=1.384952    scaled=0.000000
# covar=0.029789    scaled=0.000000
# -------- VAE pretrain epoch 5/50 --------
# total=0.070595
# representation=0.070595    scaled=0.070595
# recon=0.069875    scaled=0.069875
# kl=71.990227    scaled=0.000720
# var=0.706224    scaled=0.000000
# covar=7.891071    scaled=0.000000
# -------- VAE pretrain epoch 10/50 --------
# total=0.064239
# representation=0.064239    scaled=0.064239
# recon=0.063547    scaled=0.063547
# kl=69.206197    scaled=0.000692
# var=0.434232    scaled=0.000000
# covar=37.090229    scaled=0.000000
# -------- VAE pretrain epoch 15/50 --------
# total=0.059216
# representation=0.059216    scaled=0.059216
# recon=0.058684    scaled=0.058684
# kl=53.200266    scaled=0.000532
# var=0.452225    scaled=0.000000
# covar=76.464559    scaled=0.000000
# -------- VAE pretrain epoch 20/50 --------
# total=0.051649
# representation=0.051649    scaled=0.051649
# recon=0.051008    scaled=0.051008
# kl=64.162350    scaled=0.000642
# var=0.291256    scaled=0.000000
# covar=75.918645    scaled=0.000000
# -------- VAE pretrain epoch 25/50 --------
# total=0.046034
# representation=0.046034    scaled=0.046034
# recon=0.045329    scaled=0.045329
# kl=70.438466    scaled=0.000704
# var=0.279446    scaled=0.000000
# covar=79.054450    scaled=0.000000
# -------- VAE pretrain epoch 30/50 --------
# total=0.041055
# representation=0.041055    scaled=0.041055
# recon=0.040261    scaled=0.040261
# kl=79.415625    scaled=0.000794
# var=0.189528    scaled=0.000000
# covar=60.787693    scaled=0.000000
# -------- VAE pretrain epoch 35/50 --------
# total=0.038070
# representation=0.038070    scaled=0.038070
# recon=0.037257    scaled=0.037257
# kl=81.298619    scaled=0.000813
# var=0.199964    scaled=0.000000
# covar=49.040622    scaled=0.000000
# -------- VAE pretrain epoch 40/50 --------
# total=0.035790
# representation=0.035790    scaled=0.035790
# recon=0.034959    scaled=0.034959
# kl=83.068712    scaled=0.000831
# var=0.204889    scaled=0.000000
# covar=40.443794    scaled=0.000000
# -------- VAE pretrain epoch 45/50 --------
# total=0.034054
# representation=0.034054    scaled=0.034054
# recon=0.033219    scaled=0.033219
# kl=83.504594    scaled=0.000835
# var=0.195444    scaled=0.000000
# covar=35.230559    scaled=0.000000
# -------- VAE pretrain epoch 50/50 --------
# total=0.032667
# representation=0.032667    scaled=0.032667
# recon=0.031837    scaled=0.031837
# kl=82.978436    scaled=0.000830
# var=0.181412    scaled=0.000000
# covar=31.591226    scaled=0.000000
# Building the fixed conditional DriftXpress cache once, after pretraining...
# Fixed attraction caches built in 0.12 minutes
# Warming up the generator for 30 epochs (VAE frozen)...
# -------- Generator warmup epoch 1/30 --------
# latent_match=11.137613
# -------- Generator warmup epoch 5/30 --------
# latent_match=5.981545
# -------- Generator warmup epoch 10/30 --------
# latent_match=5.975224
# -------- Generator warmup epoch 15/30 --------
# latent_match=5.967878
# -------- Generator warmup epoch 20/30 --------
# latent_match=5.969531
# -------- Generator warmup epoch 25/30 --------
# latent_match=5.969092
# -------- Generator warmup epoch 30/30 --------
# latent_match=5.971699
# Warming up the generator with DriftXpress for 25 epochs (VAE frozen)...
# -------- Generator DriftXpress warmup epoch 1/25 --------
# drift=0.038276 raw_drift=0.067638 total=1.655562 average |V|=0.564656
# -------- Generator DriftXpress warmup epoch 5/25 --------
# drift=0.035333 raw_drift=0.062922 total=1.531905 average |V|=0.455829
# -------- Generator DriftXpress warmup epoch 10/25 --------
# drift=0.104187 raw_drift=0.164583 total=4.359992 average |V|=0.808097
# -------- Generator DriftXpress warmup epoch 15/25 --------
# drift=0.078777 raw_drift=0.158449 total=3.551678 average |V|=0.708934
# -------- Generator DriftXpress warmup epoch 20/25 --------
# drift=0.079881 raw_drift=0.151876 total=3.535501 average |V|=0.719390
# -------- Generator DriftXpress warmup epoch 25/25 --------
# drift=0.078818 raw_drift=0.145492 total=3.455729 average |V|=0.714476
# Joint learning rates: generator=0.0001, VAE/encoder-decoder=1e-05
# Pretrained fully joint conditional training started
# -------- Epoch 0 --------
# total=3.297044
# representation=0.032569    scaled=0.032569
# recon=0.031743    scaled=0.031743
# kl=82.583947    scaled=0.000826
# drift=0.108816    scaled=3.264475
# var=0.524756    scaled=0.000000
# covar=57.688925    scaled=0.000000
# reencoded drift=0.073918 raw drift=0.139593
# distances 14.054607391357422
# average |V|=0.689257
# latent std positive=1.481398
# latent std negative=1.061610
# -------- Epoch 1 --------
# total=3.105630
# representation=0.032712    scaled=0.032712
# recon=0.031887    scaled=0.031887
# kl=82.478612    scaled=0.000825
# drift=0.102431    scaled=3.072918
# var=0.525140    scaled=0.000000
# covar=58.276035    scaled=0.000000
# reencoded drift=0.069795 raw drift=0.130543
# distances 13.958786010742188
# average |V|=0.666693
# latent std positive=1.504870
# latent std negative=1.096535
# -------- Epoch 2 --------
# total=3.049205
# representation=0.032896    scaled=0.032896
# recon=0.032072    scaled=0.032072
# kl=82.411385    scaled=0.000824
# drift=0.100544    scaled=3.016309
# var=0.526050    scaled=0.000000
# covar=56.892038    scaled=0.000000
# reencoded drift=0.069270 raw drift=0.125093
# distances 13.881990432739258
# average |V|=0.667233
# latent std positive=1.462969
# latent std negative=1.081964
# -------- Epoch 3 --------
# total=2.928123
# representation=0.033105    scaled=0.033105
# recon=0.032280    scaled=0.032280
# kl=82.420878    scaled=0.000824
# drift=0.096501    scaled=2.895019
# var=0.525860    scaled=0.000000
# covar=57.065388    scaled=0.000000
# reencoded drift=0.066364 raw drift=0.120548
# distances 13.75644302368164
# average |V|=0.654333
# latent std positive=1.509591
# latent std negative=1.066182
# -------- Epoch 4 --------
# total=2.943045
# representation=0.033308    scaled=0.033308
# recon=0.032484    scaled=0.032484
# kl=82.435838    scaled=0.000824
# drift=0.096991    scaled=2.909736
# var=0.524709    scaled=0.000000
# covar=56.608428    scaled=0.000000
# reencoded drift=0.067257 raw drift=0.118935
# distances 14.119983673095703
# average |V|=0.661005
# latent std positive=1.473235
# latent std negative=1.094400
# -------- Epoch 5 --------
# total=2.853696
# representation=0.033521    scaled=0.033521
# recon=0.032697    scaled=0.032697
# kl=82.437598    scaled=0.000824
# drift=0.094006    scaled=2.820175
# var=0.523638    scaled=0.000000
# covar=55.759113    scaled=0.000000
# reencoded drift=0.065632 raw drift=0.113493
# distances 14.802468299865723
# average |V|=0.653411
# latent std positive=1.483882
# latent std negative=1.082774
# -------- Epoch 6 --------
# total=2.763264
# representation=0.033709    scaled=0.033709
# recon=0.032885    scaled=0.032885
# kl=82.478260    scaled=0.000825
# drift=0.090985    scaled=2.729554
# var=0.522491    scaled=0.000000
# covar=56.462605    scaled=0.000000
# reencoded drift=0.063344 raw drift=0.110565
# distances 14.568587303161621
# average |V|=0.642505
# latent std positive=1.491107
# latent std negative=1.093300
# -------- Epoch 7 --------
# total=2.732367
# representation=0.033886    scaled=0.033886
# recon=0.033061    scaled=0.033061
# kl=82.476627    scaled=0.000825
# drift=0.089949    scaled=2.698481
# var=0.520976    scaled=0.000000
# covar=55.208718    scaled=0.000000
# reencoded drift=0.062892 raw drift=0.108230
# distances 14.102803230285645
# average |V|=0.642179
# latent std positive=1.487109
# latent std negative=1.071992
# -------- Epoch 8 --------
# total=2.796818
# representation=0.034054    scaled=0.034054
# recon=0.033228    scaled=0.033228
# kl=82.625248    scaled=0.000826
# drift=0.092092    scaled=2.762764
# var=0.520424    scaled=0.000000
# covar=55.534856    scaled=0.000000
# reencoded drift=0.064963 raw drift=0.108515
# distances 14.515681266784668
# average |V|=0.658056
# latent std positive=1.502441
# latent std negative=1.091485
# -------- Epoch 9 --------
# total=2.757761
# representation=0.034215    scaled=0.034215
# recon=0.033387    scaled=0.033387
# kl=82.706849    scaled=0.000827
# drift=0.090785    scaled=2.723546
# var=0.519610    scaled=0.000000
# covar=55.324814    scaled=0.000000
# reencoded drift=0.064270 raw drift=0.106060
# distances 15.137752532958984
# average |V|=0.652355
# latent std positive=1.488525
# latent std negative=1.100871
# -------- Epoch 10 --------
# total=2.774567
# representation=0.034372    scaled=0.034372
# recon=0.033545    scaled=0.033545
# kl=82.689382    scaled=0.000827
# drift=0.091340    scaled=2.740195
# var=0.517544    scaled=0.000000
# covar=54.991656    scaled=0.000000
# reencoded drift=0.064817 raw drift=0.106091
# distances 14.985109329223633
# average |V|=0.651889
# latent std positive=1.506361
# latent std negative=1.078875
# -------- Epoch 11 --------
# total=2.745452
# representation=0.034522    scaled=0.034522
# recon=0.033694    scaled=0.033694
# kl=82.813099    scaled=0.000828
# drift=0.090364    scaled=2.710930
# var=0.517783    scaled=0.000000
# covar=54.947920    scaled=0.000000
# reencoded drift=0.064010 raw drift=0.105419
# distances 14.235971450805664
# average |V|=0.653549
# latent std positive=1.489909
# latent std negative=1.088506
# -------- Epoch 12 --------
# total=2.671411
# representation=0.034695    scaled=0.034695
# recon=0.033866    scaled=0.033866
# kl=82.922077    scaled=0.000829
# drift=0.087891    scaled=2.636715
# var=0.515478    scaled=0.000000
# covar=55.045837    scaled=0.000000
# reencoded drift=0.062326 raw drift=0.102256
# distances 14.699785232543945
# average |V|=0.639216
# latent std positive=1.501849
# latent std negative=1.098168
# -------- Epoch 13 --------
# total=2.733496
# representation=0.034833    scaled=0.034833
# recon=0.034002    scaled=0.034002
# kl=83.092700    scaled=0.000831
# drift=0.089955    scaled=2.698663
# var=0.514777    scaled=0.000000
# covar=54.786181    scaled=0.000000
# reencoded drift=0.064188 raw drift=0.103072
# distances 15.576327323913574
# average |V|=0.653572
# latent std positive=1.501292
# latent std negative=1.120934
# -------- Epoch 14 --------
# total=2.665849
# representation=0.034991    scaled=0.034991
# recon=0.034160    scaled=0.034160
# kl=83.085143    scaled=0.000831
# drift=0.087695    scaled=2.630858
# var=0.514289    scaled=0.000000
# covar=54.861002    scaled=0.000000
# reencoded drift=0.062397 raw drift=0.101194
# distances 14.565779685974121
# average |V|=0.644106
# latent std positive=1.459227
# latent std negative=1.105842
# -------- Epoch 15 --------
# total=2.706798
# representation=0.035120    scaled=0.035120
# recon=0.034289    scaled=0.034289
# kl=83.102343    scaled=0.000831
# drift=0.089056    scaled=2.671678
# var=0.512854    scaled=0.000000
# covar=54.923941    scaled=0.000000
# reencoded drift=0.063617 raw drift=0.101754
# distances 14.263983726501465
# average |V|=0.652841
# latent std positive=1.508571
# latent std negative=1.113909
# -------- Epoch 16 --------
# total=2.712464
# representation=0.035284    scaled=0.035284
# recon=0.034452    scaled=0.034452
# kl=83.156715    scaled=0.000832
# drift=0.089239    scaled=2.677180
# var=0.511035    scaled=0.000000
# covar=54.599470    scaled=0.000000
# reencoded drift=0.063880 raw drift=0.101439
# distances 14.920818328857422
# average |V|=0.650054
# latent std positive=1.496207
# latent std negative=1.097299
# -------- Epoch 17 --------
# total=2.667832
# representation=0.035423    scaled=0.035423
# recon=0.034591    scaled=0.034591
# kl=83.227521    scaled=0.000832
# drift=0.087747    scaled=2.632409
# var=0.510290    scaled=0.000000
# covar=54.246948    scaled=0.000000
# reencoded drift=0.062854 raw drift=0.099572
# distances 14.088480949401855
# average |V|=0.647786
# latent std positive=1.508472
# latent std negative=1.098809
# -------- Epoch 18 --------
# total=2.689694
# representation=0.035577    scaled=0.035577
# recon=0.034745    scaled=0.034745
# kl=83.189155    scaled=0.000832
# drift=0.088471    scaled=2.654117
# var=0.508854    scaled=0.000000
# covar=55.259306    scaled=0.000000
# reencoded drift=0.063373 raw drift=0.100390
# distances 15.614158630371094
# average |V|=0.653617
# latent std positive=1.528241
# latent std negative=1.106963
# -------- Epoch 19 --------
# total=2.643448
# representation=0.035711    scaled=0.035711
# recon=0.034879    scaled=0.034879
# kl=83.290255    scaled=0.000833
# drift=0.086925    scaled=2.607736
# var=0.507993    scaled=0.000000
# covar=54.108363    scaled=0.000000
# reencoded drift=0.062406 raw drift=0.098073
# distances 14.895559310913086
# average |V|=0.646515
# latent std positive=1.498554
# latent std negative=1.097972
# -------- Epoch 20 --------
# total=2.670282
# representation=0.035829    scaled=0.035829
# recon=0.034996    scaled=0.034996
# kl=83.307019    scaled=0.000833
# drift=0.087815    scaled=2.634454
# var=0.507069    scaled=0.000000
# covar=54.129054    scaled=0.000000
# reencoded drift=0.063132 raw drift=0.098731
# distances 15.59178352355957
# average |V|=0.652106
# latent std positive=1.517063
# latent std negative=1.113926
# -------- Epoch 30 --------
# total=2.595246
# representation=0.037132    scaled=0.037132
# recon=0.036295    scaled=0.036295
# kl=83.626162    scaled=0.000836
# drift=0.085270    scaled=2.558114
# var=0.498132    scaled=0.000000
# covar=54.754942    scaled=0.000000
# reencoded drift=0.061738 raw drift=0.094129
# distances 15.490748405456543
# average |V|=0.641915
# latent std positive=1.513590
# latent std negative=1.114460
# -------- Epoch 40 --------
# total=2.582522
# representation=0.038063    scaled=0.038063
# recon=0.037224    scaled=0.037224
# kl=83.875088    scaled=0.000839
# drift=0.084815    scaled=2.544459
# var=0.490381    scaled=0.000000
# covar=55.945463    scaled=0.000000
# reencoded drift=0.061734 raw drift=0.092323
# distances 14.656015396118164
# average |V|=0.642659
# latent std positive=1.558612
# latent std negative=1.149905
# -------- Epoch 50 --------
# total=2.569773
# representation=0.038657    scaled=0.038657
# recon=0.037815    scaled=0.037815
# kl=84.122894    scaled=0.000841
# drift=0.084371    scaled=2.531116
# var=0.484910    scaled=0.000000
# covar=56.309972    scaled=0.000000
# reencoded drift=0.061791 raw drift=0.090318
# distances 14.327885627746582
# average |V|=0.642591
# latent std positive=1.513489
# latent std negative=1.086965
# -------- Epoch 60 --------
# total=2.555388
# representation=0.039061    scaled=0.039061
# recon=0.038217    scaled=0.038217
# kl=84.435063    scaled=0.000844
# drift=0.083878    scaled=2.516327
# var=0.479054    scaled=0.000000
# covar=57.643708    scaled=0.000000
# reencoded drift=0.061736 raw drift=0.088566
# distances 15.128779411315918
# average |V|=0.644064
# latent std positive=1.553272
# latent std negative=1.112897
# -------- Epoch 70 --------
# total=2.516771
# representation=0.039405    scaled=0.039405
# recon=0.038559    scaled=0.038559
# kl=84.667066    scaled=0.000847
# drift=0.082579    scaled=2.477366
# var=0.473099    scaled=0.000000
# covar=57.332458    scaled=0.000000
# reencoded drift=0.061088 raw drift=0.085965
# distances 14.609336853027344
# average |V|=0.644990
# latent std positive=1.525964
# latent std negative=1.135262
# -------- Epoch 80 --------
# total=2.503778
# representation=0.039695    scaled=0.039695
# recon=0.038846    scaled=0.038846
# kl=84.842768    scaled=0.000848
# drift=0.082136    scaled=2.464083
# var=0.469249    scaled=0.000000
# covar=57.648875    scaled=0.000000
# reencoded drift=0.060974 raw drift=0.084650
# distances 15.128718376159668
# average |V|=0.642573
# latent std positive=1.603729
# latent std negative=1.173531
# -------- Epoch 90 --------
# total=2.511283
# representation=0.039880    scaled=0.039880
# recon=0.039030    scaled=0.039030
# kl=84.965442    scaled=0.000850
# drift=0.082380    scaled=2.471403
# var=0.465952    scaled=0.000000
# covar=58.780137    scaled=0.000000
# reencoded drift=0.061664 raw drift=0.082865
# distances 14.472799301147461
# average |V|=0.644272
# latent std positive=1.495622
# latent std negative=1.138744
# -------- Epoch 100 --------
# total=2.533899
# representation=0.040036    scaled=0.040036
# recon=0.039186    scaled=0.039186
# kl=84.982343    scaled=0.000850
# drift=0.083129    scaled=2.493862
# var=0.463262    scaled=0.000000
# covar=59.232408    scaled=0.000000
# reencoded drift=0.062200 raw drift=0.083716
# distances 14.365168571472168
# average |V|=0.651694
# latent std positive=1.571772
# latent std negative=1.157378
# -------- Epoch 110 --------
# total=2.535975
# representation=0.040150    scaled=0.040150
# recon=0.039299    scaled=0.039299
# kl=85.119085    scaled=0.000851
# drift=0.083194    scaled=2.495824
# var=0.459821    scaled=0.000000
# covar=59.487663    scaled=0.000000
# reencoded drift=0.062733 raw drift=0.081843
# distances 14.727272987365723
# average |V|=0.653089
# latent std positive=1.593531
# latent std negative=1.172548
# -------- Epoch 120 --------
# total=2.509498
# representation=0.040294    scaled=0.040294
# recon=0.039442    scaled=0.039442
# kl=85.123439    scaled=0.000851
# drift=0.082307    scaled=2.469205
# var=0.458630    scaled=0.000000
# covar=59.889283    scaled=0.000000
# reencoded drift=0.062023 raw drift=0.081134
# distances 15.84229850769043
# average |V|=0.650623
# latent std positive=1.552952
# latent std negative=1.136670
# -------- Epoch 130 --------
# total=2.550472
# representation=0.040393    scaled=0.040393
# recon=0.039541    scaled=0.039541
# kl=85.124506    scaled=0.000851
# drift=0.083669    scaled=2.510080
# var=0.455593    scaled=0.000000
# covar=60.059865    scaled=0.000000
# reencoded drift=0.063335 raw drift=0.081336
# distances 15.593341827392578
# average |V|=0.653923
# latent std positive=1.545032
# latent std negative=1.182124
# -------- Epoch 140 --------
# total=2.576353
# representation=0.040484    scaled=0.040484
# recon=0.039631    scaled=0.039631
# kl=85.249387    scaled=0.000852
# drift=0.084529    scaled=2.535869
# var=0.452032    scaled=0.000000
# covar=60.433478    scaled=0.000000
# reencoded drift=0.064130 raw drift=0.081596
# distances 15.174476623535156
# average |V|=0.658776
# latent std positive=1.592770
# latent std negative=1.179148
# -------- Epoch 150 --------
# total=2.516501
# representation=0.040553    scaled=0.040553
# recon=0.039702    scaled=0.039702
# kl=85.164138    scaled=0.000852
# drift=0.082532    scaled=2.475948
# var=0.450887    scaled=0.000000
# covar=60.734769    scaled=0.000000
# reencoded drift=0.062601 raw drift=0.079723
# distances 15.342840194702148
# average |V|=0.655606
# latent std positive=1.528445
# latent std negative=1.159755
# -------- Epoch 160 --------
# total=2.526527
# representation=0.040636    scaled=0.040636
# recon=0.039784    scaled=0.039784
# kl=85.213729    scaled=0.000852
# drift=0.082863    scaled=2.485891
# var=0.449447    scaled=0.000000
# covar=60.932921    scaled=0.000000
# reencoded drift=0.063330 raw drift=0.078132
# distances 15.593591690063477
# average |V|=0.657843
# latent std positive=1.541435
# latent std negative=1.140006
# -------- Epoch 170 --------
# total=2.491780
# representation=0.040750    scaled=0.040750
# recon=0.039898    scaled=0.039898
# kl=85.199408    scaled=0.000852
# drift=0.081701    scaled=2.451030
# var=0.447364    scaled=0.000000
# covar=61.058802    scaled=0.000000
# reencoded drift=0.062306 raw drift=0.077581
# distances 15.201099395751953
# average |V|=0.653561
# latent std positive=1.582331
# latent std negative=1.185452
# -------- Epoch 180 --------
# total=2.596626
# representation=0.040803    scaled=0.040803
# recon=0.039950    scaled=0.039950
# kl=85.238368    scaled=0.000852
# drift=0.085194    scaled=2.555823
# var=0.444418    scaled=0.000000
# covar=61.675741    scaled=0.000000
# reencoded drift=0.065149 raw drift=0.080179
# distances 15.196162223815918
# average |V|=0.670186
# latent std positive=1.562788
# latent std negative=1.199462
# -------- Epoch 190 --------
# total=2.503579
# representation=0.040900    scaled=0.040900
# recon=0.040046    scaled=0.040046
# kl=85.348130    scaled=0.000853
# drift=0.082089    scaled=2.462679
# var=0.443282    scaled=0.000000
# covar=61.636162    scaled=0.000000
# reencoded drift=0.062744 raw drift=0.077381
# distances 15.46472454071045
# average |V|=0.657758
# latent std positive=1.567856
# latent std negative=1.174959
# -------- Epoch 200 --------
# total=2.519936
# representation=0.040990    scaled=0.040990
# recon=0.040137    scaled=0.040137
# kl=85.345418    scaled=0.000853
# drift=0.082632    scaled=2.478946
# var=0.442661    scaled=0.000000
# covar=62.046345    scaled=0.000000
# reencoded drift=0.063420 raw drift=0.076844
# distances 14.243734359741211
# average |V|=0.659773
# latent std positive=1.543164
# latent std negative=1.162814
# Finished. Joint training took 74.71 minutes

# %%
# Optional: inspect the actual weighted gradient paths before calling backward.
import src.matryoshka as matryoshka_utils
DRIFT_CACHE = matryoshka_utils.DRIFT_CACHE
f_trained.train()
images, class_ids = next(iter(train_loader))
x = images.to(device).flatten(start_dim=1)
class_ids = class_ids.to(device)
noise = torch.randn(x.shape[0], f_trained.latent_dim, device=device)
mu, logvar, z_pos = f_trained.get_latent(x)
x_recon = f_trained.decode(z_pos)
z_raw, x_neg = f_trained.generate(noise, class_ids)
z_neg = f_trained.encode_mu(x_neg)
L_recon = matryoshka_utils.matryoshka_reconstruction_loss(f_trained.vae, z_pos, x, MATRYOSHKA_DIMS)
L_drift_reencoded, _ = conditional_drift_loss(z_neg, class_ids, DRIFT_CACHE, TEMPERATURE, MATRYOSHKA_DIMS)
L_drift_raw, _ = conditional_drift_loss(z_raw, class_ids, DRIFT_CACHE, TEMPERATURE, MATRYOSHKA_DIMS)
L_drift = L_drift_reencoded + 0.25 * L_drift_raw
print(per_loss_gradient_norms(
    {"recon": L_recon, "drift": L_drift},
    f_trained,
    {"drift": LAMBDA_DRIFT},
    lambda_representation=LAMBDA_REPRESENTATION,
))
# Out:
# {'recon': {'encoder': {'total_norm': 0.04505847266028498, 'nonzero_parameters': 8, 'parameter_count': 8}, 'decoder': {'total_norm': 0.03211439404062781, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 0.0, 'nonzero_parameters': 0, 'parameter_count': 9}}, 'drift': {'encoder': {'total_norm': 29.76326297526805, 'nonzero_parameters': 6, 'parameter_count': 8}, 'decoder': {'total_norm': 13.255644143891953, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 21.956091399639426, 'nonzero_parameters': 9, 'parameter_count': 9}}, 'total': {'encoder': {'total_norm': 29.755308771420935, 'nonzero_parameters': 8, 'parameter_count': 8}, 'decoder': {'total_norm': 13.261108499157174, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 21.956091399639426, 'nonzero_parameters': 9, 'parameter_count': 9}}}

# %%
joint_history = {
    "total": losses,
    "recon": recon_losses,
    "kl": kl_losses,
    "drift": drift_losses,
    "drift_raw": drift_raw_losses,
    "var": var_losses,
    "covar": covar_losses,
    "force": average_V,
}
fig, axes = plot_loss_history(joint_history)
plt.show()

# %%
# Full-space metrics keep the same interface; prefix metrics expose the nested behavior.
post_eval = evaluate_matryoshka_model(
    f_trained,
    test_loader,
    device=device,
    dimensions=MATRYOSHKA_DIMS,
    n_samples=2048,
    n_classes=NUM_CLASSES,
    class_to_label=CLASS_TO_DIGIT,
    include_mmd=False,
    include_fid=True,
)

samples = post_eval["samples"]
real_latents = samples["real_latents"]
generated_latents = samples["generated_latents"]
real_pixels = samples["real_images"]
generated_pixels = samples["generated_images"]
real_class_labels = samples["real_class_ids"]
generated_class_labels = samples["generated_class_ids"]
real_labels = samples["real_labels"]
generated_labels = samples["generated_labels"]
metrics = post_eval["metrics"]
latent_stats = post_eval["statistics"]

print("Latent-space metrics:")
for name, value in metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent-space metrics:
# sliced_wasserstein: 0.346427
# fid: 15.824077
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
pixel_metrics = evaluate_generation(
    real_pixels,
    generated_pixels,
    generated_labels=generated_class_labels,
    n_classes=NUM_CLASSES,
    include_mmd=False,
)
print("Pixel-space metrics:")
for name, value in pixel_metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Pixel-space metrics:
# sliced_wasserstein: 0.082584
# fid: 24.074025
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
print("Latent statistics:")
for name, value in latent_stats.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent statistics:
# real_latent_mean: -0.213885
# generated_latent_mean: -0.268233
# real_latent_std: 1.421452
# generated_latent_std: 1.144388
# generated_to_real_std_ratio: 0.805084
# real_total_correlation: 43.822772
# generated_total_correlation: 42.746744

# %%
matryoshka_metrics = post_eval["matryoshka_metrics"]
matryoshka_statistics = post_eval["matryoshka_statistics"]
prefix_reconstruction_mse = post_eval["matryoshka_reconstruction_mse"]
print("Matryoshka prefix metrics:")
for dimension in MATRYOSHKA_DIMS:
    print(f"dimension={dimension}")
    for name, value in matryoshka_metrics[dimension].items():
        print(f"{name}: {value:.6f}")
    print(f"reconstruction_mse: {prefix_reconstruction_mse[dimension]:.6f}")

fig, axes = plot_matryoshka_diagnostics(
    matryoshka_metrics,
    prefix_reconstruction_mse,
)
plt.show()
# Out:
# Matryoshka prefix metrics:
# dimension=4
# sliced_wasserstein: 0.758717
# fid: 3.348332
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.045698
# dimension=8
# sliced_wasserstein: 0.620409
# fid: 7.680458
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.037929
# dimension=16
# sliced_wasserstein: 0.479765
# fid: 12.423372
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.036280
# dimension=32
# sliced_wasserstein: 0.346427
# fid: 15.824077
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.036125

# %%
fig, axes = plot_conditional_mnist_results(
    f_trained,
    test_loader,
    device=device,
    samples=10,
    use_mean_for_reconstruction=True,
)
plt.show()

fig, axes = plot_matryoshka_reconstructions(
    f_trained,
    test_loader,
    MATRYOSHKA_DIMS,
    device=device,
    samples=10,
)
plt.show()

# %%
projection_figures = plot_real_generated_projections(
    real_latents,
    generated_latents,
    real_labels=real_labels,
    generated_labels=generated_labels,
    methods=("pca", "umap"),
)
plt.show()
# Out:
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# The prefix metric table, sweep plot, and reconstruction grid show whether the first 4/8/16 coordinates remain useful during fully joint training.
