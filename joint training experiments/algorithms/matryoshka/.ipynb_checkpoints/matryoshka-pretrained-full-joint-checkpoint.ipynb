# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms, utils
from torch.utils.data import DataLoader
# %cd "C:/Users/mateo/Desktop/polymath-jr-drifting"
import importlib
import src.matryoshka as matryoshka_utils
matryoshka_utils = importlib.reload(matryoshka_utils)
from src.driftXpress import *
from src.eval import (
    evaluate_generation,
    plot_conditional_mnist_results,
    plot_loss_history,
    plot_real_generated_projections,
)
from src.training import (
    compose_objective,
    format_epoch_losses,
    gradient_report,
    per_loss_gradient_norms,
    set_requires_grad,
)
from src.matryoshka import (
    VAE,
    LatentGenerator,
    f,
    conditional_drift_loss,
    evaluate_matryoshka_model,
    plot_matryoshka_diagnostics,
    plot_matryoshka_reconstructions,
    pretrained_full_joint_training_loop,
)
torch.manual_seed(7)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)
# Out:
# C:\Users\mateo\Desktop\polymath-jr-drifting
# Using: cuda

# %%
transform = transforms.ToTensor()

SELECTED_DIGITS = (0, 8, 2, 4, 7, 9)
DIGIT_TO_CLASS = {digit: index for index, digit in enumerate(SELECTED_DIGITS)}
CLASS_TO_DIGIT = np.asarray(SELECTED_DIGITS)

train_data = datasets.MNIST("data", train=True, download=True, transform=transform)
test_data = datasets.MNIST("data", train=False, download=True, transform=transform)

def keep_selected_digits(dataset):
    selected = torch.tensor(SELECTED_DIGITS, dtype=dataset.targets.dtype)
    mask = torch.isin(dataset.targets, selected)
    dataset.data = dataset.data[mask]
    raw_targets = dataset.targets[mask]
    dataset.targets = torch.tensor(
        [DIGIT_TO_CLASS[int(digit)] for digit in raw_targets],
        dtype=torch.long,
    )
    return dataset

train_data = keep_selected_digits(train_data)
test_data = keep_selected_digits(test_data)

BATCH_SIZE = 500

train_loader = DataLoader(
    train_data,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)
test_loader = DataLoader(
    test_data,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=torch.cuda.is_available(),
)

print("Selected digits:", SELECTED_DIGITS)
print("Train samples:", len(train_data))
print("Test samples:", len(test_data))
# Out:
# Selected digits: (0, 8, 2, 4, 7, 9)
# Train samples: 35788
# Test samples: 6005

# %%
NUM_CLASSES = 6
LATENT_DIM = 32
MATRYOSHKA_DIMS = (4, 8, 16, 32)
model = f(
    VAE(input_dim=784, latent_dim=LATENT_DIM, matryoshka_dims=MATRYOSHKA_DIMS),
    LatentGenerator(latent_dim=LATENT_DIM, num_classes=NUM_CLASSES, matryoshka_dims=MATRYOSHKA_DIMS),
    num_classes=NUM_CLASSES,
)
print(f"Total parameters: {sum(parameter.numel() for parameter in model.parameters())}")
print(f"Trainable parameters: {sum(parameter.numel() for parameter in model.parameters() if parameter.requires_grad)}")
# Out:
# Total parameters: 357280
# Trainable parameters: 357280

# %%
def training_loop(
    num_epochs,
    T,
    num_landmarks,
    lambda_kl,
    lambda_drift,
    lambda_var,
    lambda_cov,
    lambda_representation=1.0,
    loss_scale=1.0,
    vae_pretrain_epochs=50,
    generator_warmup_epochs=30,
    generator_drift_warmup_epochs=25,
    generator_lr=1e-3,
    generator_drift_lr=1e-4,
    joint_generator_lr=1e-4,
    joint_vae_lr=1e-5,
    raw_drift_weight=0.25,
    lr=1e-4,
):
    # Keep pretrained-full-joint.ipynb's call signature and return tuple.
    return pretrained_full_joint_training_loop(
        num_epochs, T, num_landmarks, lambda_kl, lambda_drift,
        lambda_var, lambda_cov,
        lambda_representation=lambda_representation,
        loss_scale=loss_scale,
        vae_pretrain_epochs=vae_pretrain_epochs,
        generator_warmup_epochs=generator_warmup_epochs,
        generator_drift_warmup_epochs=generator_drift_warmup_epochs,
        generator_lr=generator_lr,
        generator_drift_lr=generator_drift_lr,
        joint_generator_lr=joint_generator_lr,
        joint_vae_lr=joint_vae_lr,
        raw_drift_weight=raw_drift_weight,
        lr=lr,
        train_loader=train_loader,
        device=device,
        num_classes=NUM_CLASSES,
        latent_dim=LATENT_DIM,
        matryoshka_dims=MATRYOSHKA_DIMS,
    )

# %%
# Pretraining and all warmups use nested prefix losses before the fully joint phase.
VAE_PRETRAIN_EPOCHS = 50
GENERATOR_WARMUP_EPOCHS = 30
NUM_EPOCHS = 200
NUM_LANDMARKS = 200
TEMPERATURE = 2
LAMBDA_KL = 1e-5
LAMBDA_DRIFT = 30.0
LAMBDA_VAR = 0.0
LAMBDA_COV = 0.0
LAMBDA_REPRESENTATION = 1.0
LOSS_SCALE = 1.0  # Keep at 1.0; it is an intentional global gradient-scale test.

(
    f_trained,
    losses,
    recon_losses,
    kl_losses,
    drift_losses,
    var_losses,
    covar_losses,
    average_V,
    evolution,
    pretrain_history,
    generator_warmup_history,
    generator_drift_history,
    drift_raw_losses,
) = training_loop(
    NUM_EPOCHS,
    TEMPERATURE,
    NUM_LANDMARKS,
    LAMBDA_KL,
    LAMBDA_DRIFT,
    LAMBDA_VAR,
    LAMBDA_COV,
    lambda_representation=LAMBDA_REPRESENTATION,
    loss_scale=LOSS_SCALE,
    vae_pretrain_epochs=VAE_PRETRAIN_EPOCHS,
    generator_warmup_epochs=GENERATOR_WARMUP_EPOCHS,
    generator_drift_warmup_epochs=25,
    generator_lr=1e-3,
    generator_drift_lr=1e-4,
    joint_generator_lr=1e-4,
    joint_vae_lr=1e-5,
    raw_drift_weight=0.25,
    lr=1e-4,
)
# Out:
# Pretraining the VAE part for 50 epochs (generator frozen)...
# -------- VAE pretrain epoch 1/50 --------
# total=0.349282
# representation=0.349282    scaled=0.349282
# recon=0.213488    scaled=0.213488
# kl=0.947623    scaled=0.000009
# var=1.334668    scaled=0.133467
# covar=0.007726    scaled=0.002318
# -------- VAE pretrain epoch 5/50 --------
# total=0.144699
# representation=0.144699    scaled=0.144699
# recon=0.068058    scaled=0.068058
# kl=32.152886    scaled=0.000322
# var=0.678349    scaled=0.067835
# covar=0.028282    scaled=0.008485
# -------- VAE pretrain epoch 10/50 --------
# total=0.129136
# representation=0.129136    scaled=0.129136
# recon=0.054931    scaled=0.054931
# kl=29.559568    scaled=0.000296
# var=0.653740    scaled=0.065374
# covar=0.028450    scaled=0.008535
# -------- VAE pretrain epoch 15/50 --------
# total=0.121559
# representation=0.121559    scaled=0.121559
# recon=0.049710    scaled=0.049710
# kl=35.029427    scaled=0.000350
# var=0.623983    scaled=0.062398
# covar=0.030335    scaled=0.009101
# -------- VAE pretrain epoch 20/50 --------
# total=0.114618
# representation=0.114618    scaled=0.114618
# recon=0.045625    scaled=0.045625
# kl=41.825264    scaled=0.000418
# var=0.589139    scaled=0.058914
# covar=0.032204    scaled=0.009661
# -------- VAE pretrain epoch 25/50 --------
# total=0.105039
# representation=0.105039    scaled=0.105039
# recon=0.042382    scaled=0.042382
# kl=49.019939    scaled=0.000490
# var=0.523710    scaled=0.052371
# covar=0.032655    scaled=0.009796
# -------- VAE pretrain epoch 30/50 --------
# total=0.102179
# representation=0.102179    scaled=0.102179
# recon=0.040039    scaled=0.040039
# kl=51.076017    scaled=0.000511
# var=0.504482    scaled=0.050448
# covar=0.037271    scaled=0.011181
# -------- VAE pretrain epoch 35/50 --------
# total=0.099557
# representation=0.099557    scaled=0.099557
# recon=0.038197    scaled=0.038197
# kl=54.270108    scaled=0.000543
# var=0.495541    scaled=0.049554
# covar=0.037547    scaled=0.011264
# -------- VAE pretrain epoch 40/50 --------
# total=0.095896
# representation=0.095896    scaled=0.095896
# recon=0.036857    scaled=0.036857
# kl=56.845681    scaled=0.000568
# var=0.476871    scaled=0.047687
# covar=0.035946    scaled=0.010784
# -------- VAE pretrain epoch 45/50 --------
# total=0.091727
# representation=0.091727    scaled=0.091727
# recon=0.035885    scaled=0.035885
# kl=58.908445    scaled=0.000589
# var=0.432757    scaled=0.043276
# covar=0.039924    scaled=0.011977
# -------- VAE pretrain epoch 50/50 --------
# total=0.089421
# representation=0.089421    scaled=0.089421
# recon=0.034970    scaled=0.034970
# kl=59.420674    scaled=0.000594
# var=0.392483    scaled=0.039248
# covar=0.048696    scaled=0.014609
# Building the fixed conditional DriftXpress cache once, after pretraining...
# Fixed attraction caches built in 0.11 minutes
# Warming up the generator for 30 epochs (VAE frozen)...
# -------- Generator warmup epoch 1/30 --------
# latent_match=3.291722
# -------- Generator warmup epoch 5/30 --------
# latent_match=1.124042
# -------- Generator warmup epoch 10/30 --------
# latent_match=1.107922
# -------- Generator warmup epoch 15/30 --------
# latent_match=1.106633
# -------- Generator warmup epoch 20/30 --------
# latent_match=1.106747
# -------- Generator warmup epoch 25/30 --------
# latent_match=1.106087
# -------- Generator warmup epoch 30/30 --------
# latent_match=1.106743
# Warming up the generator with DriftXpress for 25 epochs (VAE frozen)...
# -------- Generator DriftXpress warmup epoch 1/25 --------
# drift=0.015561 raw_drift=0.016760 total=0.592533 average |V|=0.345474
# -------- Generator DriftXpress warmup epoch 5/25 --------
# drift=0.005304 raw_drift=0.022108 total=0.324923 average |V|=0.205346
# -------- Generator DriftXpress warmup epoch 10/25 --------
# drift=0.007199 raw_drift=0.021909 total=0.380273 average |V|=0.238852
# -------- Generator DriftXpress warmup epoch 15/25 --------
# drift=0.009228 raw_drift=0.021914 total=0.441183 average |V|=0.270477
# -------- Generator DriftXpress warmup epoch 20/25 --------
# drift=0.010202 raw_drift=0.022114 total=0.471925 average |V|=0.284120
# -------- Generator DriftXpress warmup epoch 25/25 --------
# drift=0.010856 raw_drift=0.022733 total=0.496169 average |V|=0.292377
# Joint learning rates: generator=0.0001, VAE/encoder-decoder=1e-05
# Pretrained fully joint conditional training started
# -------- Epoch 0 --------
# total=0.658496
# representation=0.243624    scaled=0.243624
# recon=0.034928    scaled=0.034928
# kl=59.374515    scaled=0.000594
# drift=0.013829    scaled=0.414872
# var=1.061214    scaled=0.106121
# covar=0.339935    scaled=0.101981
# reencoded drift=0.008739 raw drift=0.020362
# distances 6.049158573150635
# average |V|=0.258133
# latent std positive=0.604370
# latent std negative=0.338287
# -------- Epoch 1 --------
# total=0.632594
# representation=0.235215    scaled=0.235215
# recon=0.035050    scaled=0.035050
# kl=59.119067    scaled=0.000591
# drift=0.013246    scaled=0.397379
# var=1.064252    scaled=0.106425
# covar=0.310494    scaled=0.093148
# reencoded drift=0.008769 raw drift=0.017908
# distances 5.851887226104736
# average |V|=0.256861
# latent std positive=0.614489
# latent std negative=0.350526
# -------- Epoch 2 --------
# total=0.606914
# representation=0.231068    scaled=0.231068
# recon=0.035225    scaled=0.035225
# kl=58.873712    scaled=0.000589
# drift=0.012528    scaled=0.375846
# var=1.061023    scaled=0.106102
# covar=0.297174    scaled=0.089152
# reencoded drift=0.008391 raw drift=0.016549
# distances 5.979878902435303
# average |V|=0.250826
# latent std positive=0.605937
# latent std negative=0.355907
# -------- Epoch 3 --------
# total=0.604789
# representation=0.229001    scaled=0.229001
# recon=0.035446    scaled=0.035446
# kl=58.690288    scaled=0.000587
# drift=0.012526    scaled=0.375787
# var=1.056620    scaled=0.105662
# covar=0.291022    scaled=0.087307
# reencoded drift=0.008554 raw drift=0.015887
# distances 6.009209156036377
# average |V|=0.252950
# latent std positive=0.612842
# latent std negative=0.358856
# -------- Epoch 4 --------
# total=0.594888
# representation=0.226425    scaled=0.226425
# recon=0.035657    scaled=0.035657
# kl=58.553850    scaled=0.000586
# drift=0.012282    scaled=0.368463
# var=1.054195    scaled=0.105419
# covar=0.282540    scaled=0.084762
# reencoded drift=0.008489 raw drift=0.015173
# distances 6.023881912231445
# average |V|=0.252556
# latent std positive=0.604671
# latent std negative=0.363743
# -------- Epoch 5 --------
# total=0.593487
# representation=0.222783    scaled=0.222783
# recon=0.035899    scaled=0.035899
# kl=58.455446    scaled=0.000585
# drift=0.012357    scaled=0.370704
# var=1.051700    scaled=0.105170
# covar=0.270430    scaled=0.081129
# reencoded drift=0.008675 raw drift=0.014726
# distances 5.974799156188965
# average |V|=0.253690
# latent std positive=0.602729
# latent std negative=0.370837
# -------- Epoch 6 --------
# total=0.583088
# representation=0.221407    scaled=0.221407
# recon=0.036110    scaled=0.036110
# kl=58.311739    scaled=0.000583
# drift=0.012056    scaled=0.361681
# var=1.047277    scaled=0.104728
# covar=0.266621    scaled=0.079986
# reencoded drift=0.008477 raw drift=0.014318
# distances 6.159282684326172
# average |V|=0.251586
# latent std positive=0.606652
# latent std negative=0.371490
# -------- Epoch 7 --------
# total=0.575407
# representation=0.217108    scaled=0.217108
# recon=0.036306    scaled=0.036306
# kl=58.226763    scaled=0.000582
# drift=0.011943    scaled=0.358299
# var=1.039785    scaled=0.103978
# covar=0.254137    scaled=0.076241
# reencoded drift=0.008444 raw drift=0.013996
# distances 5.8006591796875
# average |V|=0.251037
# latent std positive=0.608736
# latent std negative=0.374844
# -------- Epoch 8 --------
# total=0.594115
# representation=0.214364    scaled=0.214364
# recon=0.036515    scaled=0.036515
# kl=58.154703    scaled=0.000582
# drift=0.012658    scaled=0.379751
# var=1.033751    scaled=0.103375
# covar=0.246308    scaled=0.073892
# reencoded drift=0.009116 raw drift=0.014168
# distances 6.0387349128723145
# average |V|=0.261857
# latent std positive=0.604133
# latent std negative=0.385747
# -------- Epoch 9 --------
# total=0.588714
# representation=0.210870    scaled=0.210870
# recon=0.036715    scaled=0.036715
# kl=58.063813    scaled=0.000581
# drift=0.012595    scaled=0.377844
# var=1.028156    scaled=0.102816
# covar=0.235862    scaled=0.070758
# reencoded drift=0.009092 raw drift=0.014011
# distances 6.0718278884887695
# average |V|=0.260722
# latent std positive=0.611471
# latent std negative=0.384354
# -------- Epoch 10 --------
# total=0.613899
# representation=0.207854    scaled=0.207854
# recon=0.036904    scaled=0.036904
# kl=57.949459    scaled=0.000579
# drift=0.013535    scaled=0.406045
# var=1.020085    scaled=0.102009
# covar=0.227873    scaled=0.068362
# reencoded drift=0.009922 raw drift=0.014450
# distances 6.17186164855957
# average |V|=0.273302
# latent std positive=0.607645
# latent std negative=0.378043
# -------- Epoch 11 --------
# total=0.607476
# representation=0.204849    scaled=0.204849
# recon=0.037099    scaled=0.037099
# kl=57.848634    scaled=0.000578
# drift=0.013421    scaled=0.402628
# var=1.016002    scaled=0.101600
# covar=0.218571    scaled=0.065571
# reencoded drift=0.009838 raw drift=0.014332
# distances 6.087353706359863
# average |V|=0.270915
# latent std positive=0.600475
# latent std negative=0.387882
# -------- Epoch 12 --------
# total=0.619505
# representation=0.201528    scaled=0.201528
# recon=0.037297    scaled=0.037297
# kl=57.777745    scaled=0.000578
# drift=0.013933    scaled=0.417977
# var=1.005671    scaled=0.100567
# covar=0.210286    scaled=0.063086
# reencoded drift=0.010218 raw drift=0.014858
# distances 6.0065765380859375
# average |V|=0.276924
# latent std positive=0.609584
# latent std negative=0.395052
# -------- Epoch 13 --------
# total=0.628566
# representation=0.197224    scaled=0.197224
# recon=0.037464    scaled=0.037464
# kl=57.696558    scaled=0.000577
# drift=0.014378    scaled=0.431342
# var=0.998656    scaled=0.099866
# covar=0.197725    scaled=0.059317
# reencoded drift=0.010621 raw drift=0.015030
# distances 6.348960876464844
# average |V|=0.283047
# latent std positive=0.610952
# latent std negative=0.378278
# -------- Epoch 14 --------
# total=0.633112
# representation=0.193028    scaled=0.193028
# recon=0.037653    scaled=0.037653
# kl=57.591730    scaled=0.000576
# drift=0.014669    scaled=0.440084
# var=0.987114    scaled=0.098711
# covar=0.186959    scaled=0.056088
# reencoded drift=0.010797 raw drift=0.015489
# distances 6.160306930541992
# average |V|=0.284905
# latent std positive=0.603144
# latent std negative=0.398620
# -------- Epoch 15 --------
# total=0.665461
# representation=0.190791    scaled=0.190791
# recon=0.037791    scaled=0.037791
# kl=57.554054    scaled=0.000576
# drift=0.015822    scaled=0.474670
# var=0.978377    scaled=0.097838
# covar=0.181955    scaled=0.054587
# reencoded drift=0.011780 raw drift=0.016170
# distances 5.867323875427246
# average |V|=0.300271
# latent std positive=0.606639
# latent std negative=0.402188
# -------- Epoch 16 --------
# total=0.642874
# representation=0.187988    scaled=0.187988
# recon=0.037883    scaled=0.037883
# kl=57.548447    scaled=0.000575
# drift=0.015163    scaled=0.454886
# var=0.972771    scaled=0.097277
# covar=0.174175    scaled=0.052252
# reencoded drift=0.011234 raw drift=0.015717
# distances 6.156833648681641
# average |V|=0.292587
# latent std positive=0.619263
# latent std negative=0.397747
# -------- Epoch 17 --------
# total=0.647984
# representation=0.184531    scaled=0.184531
# recon=0.037976    scaled=0.037976
# kl=57.524862    scaled=0.000575
# drift=0.015448    scaled=0.463453
# var=0.964347    scaled=0.096435
# covar=0.165149    scaled=0.049545
# reencoded drift=0.011454 raw drift=0.015977
# distances 5.7203779220581055
# average |V|=0.297086
# latent std positive=0.606717
# latent std negative=0.415251
# -------- Epoch 18 --------
# total=0.638401
# representation=0.182235    scaled=0.182235
# recon=0.038034    scaled=0.038034
# kl=57.530634    scaled=0.000575
# drift=0.015206    scaled=0.456166
# var=0.961739    scaled=0.096174
# covar=0.158173    scaled=0.047452
# reencoded drift=0.011252 raw drift=0.015812
# distances 6.38619327545166
# average |V|=0.293870
# latent std positive=0.615014
# latent std negative=0.409728
# -------- Epoch 19 --------
# total=0.649992
# representation=0.179624    scaled=0.179624
# recon=0.038052    scaled=0.038052
# kl=57.582773    scaled=0.000576
# drift=0.015679    scaled=0.470368
# var=0.957253    scaled=0.095725
# covar=0.150902    scaled=0.045271
# reencoded drift=0.011699 raw drift=0.015919
# distances 6.154759407043457
# average |V|=0.299105
# latent std positive=0.607476
# latent std negative=0.410540
# -------- Epoch 20 --------
# total=0.639090
# representation=0.178469    scaled=0.178469
# recon=0.038087    scaled=0.038087
# kl=57.617589    scaled=0.000576
# drift=0.015354    scaled=0.460621
# var=0.954247    scaled=0.095425
# covar=0.147938    scaled=0.044381
# reencoded drift=0.011445 raw drift=0.015635
# distances 6.1785197257995605
# average |V|=0.296297
# latent std positive=0.617262
# latent std negative=0.411452
# -------- Epoch 30 --------
# total=0.627227
# representation=0.168797    scaled=0.168797
# recon=0.038194    scaled=0.038194
# kl=57.736107    scaled=0.000577
# drift=0.015281    scaled=0.458430
# var=0.937577    scaled=0.093758
# covar=0.120893    scaled=0.036268
# reencoded drift=0.011601 raw drift=0.014721
# distances 6.231932640075684
# average |V|=0.300043
# latent std positive=0.610982
# latent std negative=0.422594
# -------- Epoch 40 --------
# total=0.610236
# representation=0.165398    scaled=0.165398
# recon=0.038248    scaled=0.038248
# kl=57.723586    scaled=0.000577
# drift=0.014828    scaled=0.444838
# var=0.930878    scaled=0.093088
# covar=0.111617    scaled=0.033485
# reencoded drift=0.011346 raw drift=0.013930
# distances 6.145365238189697
# average |V|=0.297067
# latent std positive=0.613377
# latent std negative=0.445119
# -------- Epoch 50 --------
# total=0.634474
# representation=0.164924    scaled=0.164924
# recon=0.038373    scaled=0.038373
# kl=57.707770    scaled=0.000577
# drift=0.015652    scaled=0.469550
# var=0.927300    scaled=0.092730
# covar=0.110815    scaled=0.033244
# reencoded drift=0.012127 raw drift=0.014100
# distances 5.855459690093994
# average |V|=0.307024
# latent std positive=0.603338
# latent std negative=0.432409
# -------- Epoch 60 --------
# total=0.600857
# representation=0.162561    scaled=0.162561
# recon=0.038508    scaled=0.038508
# kl=57.562254    scaled=0.000576
# drift=0.014610    scaled=0.438296
# var=0.920977    scaled=0.092098
# covar=0.104600    scaled=0.031380
# reencoded drift=0.011274 raw drift=0.013342
# distances 6.1077985763549805
# average |V|=0.298841
# latent std positive=0.616374
# latent std negative=0.443528
# -------- Epoch 70 --------
# total=0.597232
# representation=0.161917    scaled=0.161917
# recon=0.038693    scaled=0.038693
# kl=57.349749    scaled=0.000573
# drift=0.014511    scaled=0.435316
# var=0.919832    scaled=0.091983
# covar=0.102225    scaled=0.030667
# reencoded drift=0.011298 raw drift=0.012852
# distances 5.9149980545043945
# average |V|=0.297940
# latent std positive=0.618374
# latent std negative=0.456754
# -------- Epoch 80 --------
# total=0.617605
# representation=0.159719    scaled=0.159719
# recon=0.038850    scaled=0.038850
# kl=57.399178    scaled=0.000574
# drift=0.015263    scaled=0.457885
# var=0.916700    scaled=0.091670
# covar=0.095417    scaled=0.028625
# reencoded drift=0.011903 raw drift=0.013439
# distances 6.009024143218994
# average |V|=0.305411
# latent std positive=0.625870
# latent std negative=0.461593
# -------- Epoch 90 --------
# total=0.590008
# representation=0.159351    scaled=0.159351
# recon=0.038960    scaled=0.038960
# kl=57.291475    scaled=0.000573
# drift=0.014355    scaled=0.430657
# var=0.913590    scaled=0.091359
# covar=0.094863    scaled=0.028459
# reencoded drift=0.011202 raw drift=0.012613
# distances 5.920836448669434
# average |V|=0.296829
# latent std positive=0.601362
# latent std negative=0.448732
# -------- Epoch 100 --------
# total=0.589056
# representation=0.158048    scaled=0.158048
# recon=0.039088    scaled=0.039088
# kl=57.126399    scaled=0.000571
# drift=0.014367    scaled=0.431008
# var=0.911297    scaled=0.091130
# covar=0.090864    scaled=0.027259
# reencoded drift=0.011239 raw drift=0.012512
# distances 5.945082187652588
# average |V|=0.298831
# latent std positive=0.617581
# latent std negative=0.463566
# -------- Epoch 110 --------
# total=0.590447
# representation=0.158108    scaled=0.158108
# recon=0.039188    scaled=0.039188
# kl=57.003135    scaled=0.000570
# drift=0.014411    scaled=0.432338
# var=0.907134    scaled=0.090713
# covar=0.092125    scaled=0.027637
# reencoded drift=0.011281 raw drift=0.012522
# distances 5.923547744750977
# average |V|=0.299952
# latent std positive=0.612918
# latent std negative=0.469457
# -------- Epoch 120 --------
# total=0.568028
# representation=0.156801    scaled=0.156801
# recon=0.039264    scaled=0.039264
# kl=56.958398    scaled=0.000570
# drift=0.013708    scaled=0.411227
# var=0.902390    scaled=0.090239
# covar=0.089095    scaled=0.026729
# reencoded drift=0.010648 raw drift=0.012239
# distances 6.117541313171387
# average |V|=0.290936
# latent std positive=0.612548
# latent std negative=0.462614
# -------- Epoch 130 --------
# total=0.595166
# representation=0.156818    scaled=0.156818
# recon=0.039353    scaled=0.039353
# kl=56.926501    scaled=0.000569
# drift=0.014612    scaled=0.438348
# var=0.903335    scaled=0.090334
# covar=0.088542    scaled=0.026563
# reencoded drift=0.011427 raw drift=0.012737
# distances 6.014206886291504
# average |V|=0.301199
# latent std positive=0.613759
# latent std negative=0.461917
# -------- Epoch 140 --------
# total=0.582701
# representation=0.156233    scaled=0.156233
# recon=0.039398    scaled=0.039398
# kl=56.885085    scaled=0.000569
# drift=0.014216    scaled=0.426468
# var=0.899605    scaled=0.089961
# covar=0.087686    scaled=0.026306
# reencoded drift=0.011158 raw drift=0.012228
# distances 5.868221759796143
# average |V|=0.299375
# latent std positive=0.618502
# latent std negative=0.467824
# -------- Epoch 150 --------
# total=0.584151
# representation=0.156247    scaled=0.156247
# recon=0.039426    scaled=0.039426
# kl=56.945184    scaled=0.000569
# drift=0.014263    scaled=0.427904
# var=0.897208    scaled=0.089721
# covar=0.088435    scaled=0.026530
# reencoded drift=0.011190 raw drift=0.012294
# distances 6.2725114822387695
# average |V|=0.299323
# latent std positive=0.617630
# latent std negative=0.460831
# -------- Epoch 160 --------
# total=0.597341
# representation=0.155834    scaled=0.155834
# recon=0.039456    scaled=0.039456
# kl=56.776535    scaled=0.000568
# drift=0.014717    scaled=0.441507
# var=0.896165    scaled=0.089616
# covar=0.087311    scaled=0.026193
# reencoded drift=0.011555 raw drift=0.012650
# distances 6.029696464538574
# average |V|=0.304430
# latent std positive=0.609793
# latent std negative=0.453136
# -------- Epoch 170 --------
# total=0.598312
# representation=0.155110    scaled=0.155110
# recon=0.039498    scaled=0.039498
# kl=56.822690    scaled=0.000568
# drift=0.014773    scaled=0.443201
# var=0.891979    scaled=0.089198
# covar=0.086153    scaled=0.025846
# reencoded drift=0.011641 raw drift=0.012528
# distances 6.221679210662842
# average |V|=0.304633
# latent std positive=0.628859
# latent std negative=0.475314
# -------- Epoch 180 --------
# total=0.596918
# representation=0.154261    scaled=0.154261
# recon=0.039525    scaled=0.039525
# kl=56.811524    scaled=0.000568
# drift=0.014755    scaled=0.442657
# var=0.891429    scaled=0.089143
# covar=0.083415    scaled=0.025025
# reencoded drift=0.011590 raw drift=0.012662
# distances 6.08107328414917
# average |V|=0.303992
# latent std positive=0.616453
# latent std negative=0.474527
# -------- Epoch 190 --------
# total=0.601803
# representation=0.153987    scaled=0.153987
# recon=0.039516    scaled=0.039516
# kl=56.812816    scaled=0.000568
# drift=0.014927    scaled=0.447815
# var=0.888732    scaled=0.088873
# covar=0.083434    scaled=0.025030
# reencoded drift=0.011738 raw drift=0.012757
# distances 6.129284381866455
# average |V|=0.306927
# latent std positive=0.618026
# latent std negative=0.467624
# -------- Epoch 200 --------
# total=0.581065
# representation=0.153587    scaled=0.153587
# recon=0.039546    scaled=0.039546
# kl=56.761212    scaled=0.000568
# drift=0.014249    scaled=0.427478
# var=0.888134    scaled=0.088813
# covar=0.082201    scaled=0.024660
# reencoded drift=0.011236 raw drift=0.012054
# distances 5.88947868347168
# average |V|=0.299402
# latent std positive=0.614079
# latent std negative=0.460122
# Finished. Joint training took 70.91 minutes

# %%
# Optional: inspect the actual weighted gradient paths before calling backward.
import src.matryoshka as matryoshka_utils
DRIFT_CACHE = matryoshka_utils.DRIFT_CACHE
f_trained.train()
images, class_ids = next(iter(train_loader))
x = images.to(device).flatten(start_dim=1)
class_ids = class_ids.to(device)
noise = torch.randn(x.shape[0], f_trained.latent_dim, device=device)
mu, logvar, z_pos = f_trained.get_latent(x)
x_recon = f_trained.decode(z_pos)
z_raw, x_neg = f_trained.generate(noise, class_ids)
z_neg = f_trained.encode_mu(x_neg)
L_recon = matryoshka_utils.matryoshka_reconstruction_loss(f_trained.vae, z_pos, x, MATRYOSHKA_DIMS)
L_drift_reencoded, _ = conditional_drift_loss(z_neg, class_ids, DRIFT_CACHE, TEMPERATURE, MATRYOSHKA_DIMS)
L_drift_raw, _ = conditional_drift_loss(z_raw, class_ids, DRIFT_CACHE, TEMPERATURE, MATRYOSHKA_DIMS)
L_drift = L_drift_reencoded + 0.25 * L_drift_raw
print(per_loss_gradient_norms(
    {"recon": L_recon, "drift": L_drift},
    f_trained,
    {"drift": LAMBDA_DRIFT},
    lambda_representation=LAMBDA_REPRESENTATION,
))
# Out:
# {'recon': {'encoder': {'total_norm': 0.018722467463228008, 'nonzero_parameters': 8, 'parameter_count': 8}, 'decoder': {'total_norm': 0.018833568001832158, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 0.0, 'nonzero_parameters': 0, 'parameter_count': 9}}, 'drift': {'encoder': {'total_norm': 14.34674656673942, 'nonzero_parameters': 6, 'parameter_count': 8}, 'decoder': {'total_norm': 9.682116218156255, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 12.34579094536044, 'nonzero_parameters': 9, 'parameter_count': 9}}, 'total': {'encoder': {'total_norm': 14.351857731495382, 'nonzero_parameters': 8, 'parameter_count': 8}, 'decoder': {'total_norm': 9.686179220222094, 'nonzero_parameters': 6, 'parameter_count': 6}, 'generator': {'total_norm': 12.34579094536044, 'nonzero_parameters': 9, 'parameter_count': 9}}}

# %%
joint_history = {
    "total": losses,
    "recon": recon_losses,
    "kl": kl_losses,
    "drift": drift_losses,
    "drift_raw": drift_raw_losses,
    "var": var_losses,
    "covar": covar_losses,
    "force": average_V,
}
fig, axes = plot_loss_history(joint_history)
plt.show()

# %%
# Full-space metrics keep the same interface; prefix metrics expose the nested behavior.
post_eval = evaluate_matryoshka_model(
    f_trained,
    test_loader,
    device=device,
    dimensions=MATRYOSHKA_DIMS,
    n_samples=2048,
    n_classes=NUM_CLASSES,
    class_to_label=CLASS_TO_DIGIT,
    include_mmd=False,
    include_fid=True,
)

samples = post_eval["samples"]
real_latents = samples["real_latents"]
generated_latents = samples["generated_latents"]
real_pixels = samples["real_images"]
generated_pixels = samples["generated_images"]
real_class_labels = samples["real_class_ids"]
generated_class_labels = samples["generated_class_ids"]
real_labels = samples["real_labels"]
generated_labels = samples["generated_labels"]
metrics = post_eval["metrics"]
latent_stats = post_eval["statistics"]

print("Latent-space metrics:")
for name, value in metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent-space metrics:
# sliced_wasserstein: 0.168397
# fid: 3.117505
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
pixel_metrics = evaluate_generation(
    real_pixels,
    generated_pixels,
    generated_labels=generated_class_labels,
    n_classes=NUM_CLASSES,
    include_mmd=False,
)
print("Pixel-space metrics:")
for name, value in pixel_metrics.items():
    print(f"{name}: {value:.6f}")
# Out:
# Pixel-space metrics:
# sliced_wasserstein: 0.083177
# fid: 23.619062
# class_coverage: 1.000000
# class_entropy: 0.999253

# %%
print("Latent statistics:")
for name, value in latent_stats.items():
    print(f"{name}: {value:.6f}")
# Out:
# Latent statistics:
# real_latent_mean: -0.004470
# generated_latent_mean: 0.011766
# real_latent_std: 0.555599
# generated_latent_std: 0.465664
# generated_to_real_std_ratio: 0.838130
# real_total_correlation: 28.775559
# generated_total_correlation: 25.940267

# %%
matryoshka_metrics = post_eval["matryoshka_metrics"]
matryoshka_statistics = post_eval["matryoshka_statistics"]
prefix_reconstruction_mse = post_eval["matryoshka_reconstruction_mse"]
print("Matryoshka prefix metrics:")
for dimension in MATRYOSHKA_DIMS:
    print(f"dimension={dimension}")
    for name, value in matryoshka_metrics[dimension].items():
        print(f"{name}: {value:.6f}")
    print(f"reconstruction_mse: {prefix_reconstruction_mse[dimension]:.6f}")

fig, axes = plot_matryoshka_diagnostics(
    matryoshka_metrics,
    prefix_reconstruction_mse,
)
plt.show()
# Out:
# Matryoshka prefix metrics:
# dimension=4
# sliced_wasserstein: 0.372691
# fid: 0.804170
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.047764
# dimension=8
# sliced_wasserstein: 0.314773
# fid: 1.746829
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.038524
# dimension=16
# sliced_wasserstein: 0.224605
# fid: 2.351379
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.035080
# dimension=32
# sliced_wasserstein: 0.168397
# fid: 3.117505
# class_coverage: 1.000000
# class_entropy: 0.999253
# reconstruction_mse: 0.034698

# %%
fig, axes = plot_conditional_mnist_results(
    f_trained,
    test_loader,
    device=device,
    samples=10,
    use_mean_for_reconstruction=True,
)
plt.show()

fig, axes = plot_matryoshka_reconstructions(
    f_trained,
    test_loader,
    MATRYOSHKA_DIMS,
    device=device,
    samples=10,
)
plt.show()

# %%
projection_figures = plot_real_generated_projections(
    real_latents,
    generated_latents,
    real_labels=real_labels,
    generated_labels=generated_labels,
    methods=("pca", "umap"),
)
plt.show()
# Out:
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# C:\Users\mateo\anaconda3\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# The prefix metric table, sweep plot, and reconstruction grid show whether the first 4/8/16 coordinates remain useful during fully joint training.
